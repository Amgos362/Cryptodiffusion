# %%
import time
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import pyupbit

# --- 전처리 함수 ---
def rolling_minmax_scale(series, window=6):
    roll_min = series.rolling(window=window, min_periods=window).min()
    roll_max = series.rolling(window=window, min_periods=window).max()
    scaled = (series - roll_min) / ((roll_max - roll_min) + 1e-8)
    scaled = scaled.replace([np.inf, -np.inf], np.nan)
    scaled = scaled.fillna(1.0)
    return scaled.clip(upper=1.0)

def bin_and_encode(data, features, bins=100, drop_original=True):
    for feature in features:
        data[f'{feature}_Bin'] = pd.cut(data[feature], bins=bins, labels=False)
        one_hot = pd.get_dummies(data[f'{feature}_Bin'], prefix=f'{feature}_Bin').astype(np.int32)
        expected_columns = [f'{feature}_Bin_{i}' for i in range(bins)]
        one_hot = one_hot.reindex(columns=expected_columns, fill_value=0)
        data = pd.concat([data, one_hot], axis=1)
        if drop_original:
            data.drop(columns=[f'{feature}_Bin'], inplace=True)
    numeric_cols = data.select_dtypes(include=[np.number]).columns.tolist()
    for col in numeric_cols:
        data[col] = data[col].astype(np.float32)
    return data

# --- Diffusion Model 구성 ---
class ConditionEncoder(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim):
        super(ConditionEncoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim * lookback, condition_dim),
            nn.ReLU(),
            nn.Linear(condition_dim, condition_dim)
        )
        
    def forward(self, x):
        # x: [batch, lookback, input_dim]
        batch_size = x.size(0)
        x = x.contiguous().view(batch_size, -1)
        return self.fc(x)

class DiffusionClassifier(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim=128, num_timesteps=100, hidden_dim=128):
        super(DiffusionClassifier, self).__init__()
        self.num_timesteps = num_timesteps
        # diffusion 스케줄 (선형 beta schedule)
        betas = torch.linspace(1e-4, 0.02, num_timesteps)
        alphas = 1 - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)
        self.register_buffer('betas', betas)
        self.register_buffer('alphas', alphas)
        self.register_buffer('alphas_cumprod', alphas_cumprod)
        
        # 조건 인코더: 시계열 window를 임베딩
        self.condition_encoder = ConditionEncoder(input_dim, lookback, condition_dim)
        # timestep 임베딩
        self.time_embedding = nn.Embedding(num_timesteps, hidden_dim)
        # 노이즈 예측 네트워크
        self.model = nn.Sequential(
            nn.Linear(1 + condition_dim + hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )
        
    def forward(self, x_condition, y_noisy, t):
        # x_condition: [batch, lookback, input_dim]
        # y_noisy: [batch, 1]
        # t: [batch]
        cond = self.condition_encoder(x_condition)           # [batch, condition_dim]
        t_emb = self.time_embedding(t)                         # [batch, hidden_dim]
        inp = torch.cat([y_noisy, cond, t_emb], dim=1)          # [batch, 1 + condition_dim + hidden_dim]
        predicted_noise = self.model(inp)                      # [batch, 1]
        return predicted_noise
    
    def sample(self, x_condition, device):
        """
        reverse diffusion 과정을 통해 조건 x_condition에 대해 예측값을 샘플링.
        최종 출력은 continuous 값으로, 임계값 0.5를 기준으로 상승/하락을 결정.
        """
        batch_size = x_condition.size(0)
        # 초기 y: 정규분포 노이즈
        y = torch.randn(batch_size, 1, device=device)
        for t in reversed(range(self.num_timesteps)):
            t_tensor = torch.full((batch_size,), t, device=device, dtype=torch.long)
            predicted_noise = self.forward(x_condition, y, t_tensor)
            alpha = self.alphas[t]
            alpha_cumprod = self.alphas_cumprod[t]
            beta = self.betas[t]
            y = (1 / torch.sqrt(alpha)) * (y - (beta / torch.sqrt(1 - alpha_cumprod)) * predicted_noise)
            if t > 0:
                noise = torch.randn_like(y)
                y = y + torch.sqrt(beta) * noise
        return y

# --- 모델 로드 ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# OHLC 4개 feature를 100구간으로 binning했으므로 입력 차원은 4*100 = 400
input_dim = 400
lookback = 6
model = DiffusionClassifier(input_dim=input_dim, lookback=lookback, condition_dim=128, num_timesteps=100, hidden_dim=128).to(device)
model_path = "diffusion_model_experiment_14_6.pth"  # 실제 학습된 모델 파일 경로로 수정
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# --- pyupbit API 설정 ---
access = "x03uKM3uyZ9RNDBHLxauEaeI6X8pdKQq8rHG2wvx"
secret = "e9UyPqJBjCvNDxCmtx7bdPaHtAEgw2Ftxu3UpuJc"
upbit = pyupbit.Upbit(access, secret)
ticker = "KRW-ETH"  # 거래할 코인 티커

# --- 예측 함수 ---
def get_model_prediction():
    """
    pyupbit로 최근 50개의 5분봉 데이터를 가져와 전처리한 후,
    마지막 24개 봉을 diffusion model의 조건으로 사용하여
    reverse diffusion sampling을 통해 다음 5분봉 상승/하락 예측(1: 상승, 0: 하락)을 반환.
    """
    df = pyupbit.get_ohlcv(ticker, interval="minute5", count=15)
    if df is None or len(df) < lookback:
        print("예측에 충분한 데이터가 없습니다.")
        return None
    ohlc_features = ['open', 'high', 'low', 'close']
    for feature in ohlc_features:
        df[feature] = rolling_minmax_scale(df[feature], window=6)
    df_processed = bin_and_encode(df.copy(), ohlc_features, bins=100, drop_original=True)
    final_input_columns = [col for col in df_processed.columns if '_Bin_' in col]
    if len(df_processed) < lookback:
        print("lookback 데이터가 부족합니다.")
        return None
    input_seq = df_processed[final_input_columns].iloc[-lookback:]
    # 모델 입력 형태: [batch, seq_len, features]
    x = torch.tensor(input_seq.values, dtype=torch.float32).unsqueeze(0).to(device)
    with torch.no_grad():
        y_cont = model.sample(x, device)  # continuous output
        prediction = 1 if y_cont.item() >= 0.5 else 0
    return prediction

# --- 거래 함수 ---
def trade_decision():
    prediction = get_model_prediction()
    if prediction is None:
        return
    print(f"모델 예측 결과 (1: 상승, 0: 하락): {prediction}")
    if prediction == 1:
        # 상승 예측 시: 보유 KRW의 20%로 매수
        krw_balance = upbit.get_balance("KRW")
        if krw_balance is None or krw_balance < 5000:
            print("매수할 충분한 KRW 잔고가 없습니다.")
            return
        trade_amount = krw_balance * 0.25
        print(f"{ticker}을(를) {trade_amount:.0f} KRW로 매수합니다.")
        upbit.buy_market_order(ticker, trade_amount)
    else:
        # 하락 예측 시: 보유 코인의 20% 매도
        coin = ticker.split("-")[1]
        coin_balance = upbit.get_balance(coin)
        if coin_balance is None or coin_balance <= 0:
            print("매도할 보유 코인이 없습니다.")
            return
        trade_amount = coin_balance * 0.5
        print(f"{coin}의 {trade_amount:.4f}개를 매도합니다.")
        upbit.sell_market_order(ticker, trade_amount)

# --- 메인 루프: 새로운 5분봉이 생성될 때마다 업데이트 ---
last_candle_time = None
while True:
    try:
        # 최신 5분봉 데이터 1개 (마지막 봉)
        df = pyupbit.get_ohlcv(ticker, interval="minute5", count=1)
        if df is not None and not df.empty:
            current_candle_time = df.index[-1]
            # 새로운 봉이 생성되었으면 trade_decision() 실행
            if last_candle_time is None or current_candle_time > last_candle_time:
                last_candle_time = current_candle_time
                print(f"새로운 5분봉 생성: {last_candle_time}")
                trade_decision()
        else:
            print("최신 5분봉 데이터를 불러오지 못했습니다.")
    except Exception as e:
        print(f"에러 발생: {e}")
    # 10초마다 확인 (필요에 따라 sleep 시간을 조정)
    time.sleep(10)
# Out:
# 새로운 5분봉 생성: 2025-03-16 11:00:00
# 모델 예측 결과 (1: 상승, 0: 하락): 0
# 매도할 보유 코인이 없습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 187
#     185     print(f"에러 발생: {e}")
#     186 # 10초마다 확인 (필요에 따라 sleep 시간을 조정)
# --> 187 time.sleep(10)
#
# KeyboardInterrupt:

# %%
import time
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import pyupbit

# --- 전처리 함수 ---
def rolling_minmax_scale(series, window=6):
    roll_min = series.rolling(window=window, min_periods=window).min()
    roll_max = series.rolling(window=window, min_periods=window).max()
    scaled = (series - roll_min) / ((roll_max - roll_min) + 1e-8)
    scaled = scaled.replace([np.inf, -np.inf], np.nan)
    scaled = scaled.fillna(1.0)
    return scaled.clip(upper=1.0)

def bin_and_encode(data, features, bins=100, drop_original=True):
    for feature in features:
        data[f'{feature}_Bin'] = pd.cut(data[feature], bins=bins, labels=False)
        one_hot = pd.get_dummies(data[f'{feature}_Bin'], prefix=f'{feature}_Bin').astype(np.int32)
        expected_columns = [f'{feature}_Bin_{i}' for i in range(bins)]
        one_hot = one_hot.reindex(columns=expected_columns, fill_value=0)
        data = pd.concat([data, one_hot], axis=1)
        if drop_original:
            data.drop(columns=[f'{feature}_Bin'], inplace=True)
    numeric_cols = data.select_dtypes(include=[np.number]).columns.tolist()
    for col in numeric_cols:
        data[col] = data[col].astype(np.float32)
    return data

# --- Diffusion Model 구성 ---
class ConditionEncoder(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim):
        super(ConditionEncoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim * lookback, condition_dim),
            nn.ReLU(),
            nn.Linear(condition_dim, condition_dim)
        )
        
    def forward(self, x):
        # x: [batch, lookback, input_dim]
        batch_size = x.size(0)
        x = x.contiguous().view(batch_size, -1)
        return self.fc(x)

class DiffusionClassifier(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim=128, num_timesteps=100, hidden_dim=128):
        super(DiffusionClassifier, self).__init__()
        self.num_timesteps = num_timesteps
        # diffusion 스케줄 (선형 beta schedule)
        betas = torch.linspace(1e-4, 0.02, num_timesteps)
        alphas = 1 - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)
        self.register_buffer('betas', betas)
        self.register_buffer('alphas', alphas)
        self.register_buffer('alphas_cumprod', alphas_cumprod)
        
        # 조건 인코더: 시계열 window를 임베딩
        self.condition_encoder = ConditionEncoder(input_dim, lookback, condition_dim)
        # timestep 임베딩
        self.time_embedding = nn.Embedding(num_timesteps, hidden_dim)
        # 노이즈 예측 네트워크
        self.model = nn.Sequential(
            nn.Linear(1 + condition_dim + hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )
        
    def forward(self, x_condition, y_noisy, t):
        # x_condition: [batch, lookback, input_dim]
        # y_noisy: [batch, 1]
        # t: [batch]
        cond = self.condition_encoder(x_condition)           # [batch, condition_dim]
        t_emb = self.time_embedding(t)                         # [batch, hidden_dim]
        inp = torch.cat([y_noisy, cond, t_emb], dim=1)          # [batch, 1 + condition_dim + hidden_dim]
        predicted_noise = self.model(inp)                      # [batch, 1]
        return predicted_noise
    
    def sample(self, x_condition, device):
        """
        reverse diffusion 과정을 통해 조건 x_condition에 대해 예측값을 샘플링.
        최종 출력은 continuous 값으로, 임계값 0.5를 기준으로 상승/하락을 결정.
        """
        batch_size = x_condition.size(0)
        # 초기 y: 정규분포 노이즈
        y = torch.randn(batch_size, 1, device=device)
        for t in reversed(range(self.num_timesteps)):
            t_tensor = torch.full((batch_size,), t, device=device, dtype=torch.long)
            predicted_noise = self.forward(x_condition, y, t_tensor)
            alpha = self.alphas[t]
            alpha_cumprod = self.alphas_cumprod[t]
            beta = self.betas[t]
            y = (1 / torch.sqrt(alpha)) * (y - (beta / torch.sqrt(1 - alpha_cumprod)) * predicted_noise)
            if t > 0:
                noise = torch.randn_like(y)
                y = y + torch.sqrt(beta) * noise
        return y

# --- 모델 로드 ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# OHLC 4개 feature를 100구간으로 binning했으므로 입력 차원은 4*100 = 400
input_dim = 400
lookback = 6
model = DiffusionClassifier(input_dim=input_dim, lookback=lookback, condition_dim=128, num_timesteps=100, hidden_dim=128).to(device)
model_path = "diffusion_model_experiment_14_6.pth"  # 실제 학습된 모델 파일 경로로 수정
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# --- pyupbit API 설정 ---
access = "x03uKM3uyZ9RNDBHLxauEaeI6X8pdKQq8rHG2wvx"
secret = "e9UyPqJBjCvNDxCmtx7bdPaHtAEgw2Ftxu3UpuJc"
upbit = pyupbit.Upbit(access, secret)
ticker = "KRW-ETH"  # 거래할 코인 티커

# --- 예측 함수 ---
def get_model_prediction():
    """
    pyupbit로 최근 50개의 5분봉 데이터를 가져와 전처리한 후,
    마지막 24개 봉을 diffusion model의 조건으로 사용하여
    reverse diffusion sampling을 통해 다음 5분봉 상승/하락 예측(1: 상승, 0: 하락)을 반환.
    """
    df = pyupbit.get_ohlcv(ticker, interval="minute5", count=15)
    if df is None or len(df) < lookback:
        print("예측에 충분한 데이터가 없습니다.")
        return None
    ohlc_features = ['open', 'high', 'low', 'close']
    for feature in ohlc_features:
        df[feature] = rolling_minmax_scale(df[feature], window=6)
    df_processed = bin_and_encode(df.copy(), ohlc_features, bins=100, drop_original=True)
    final_input_columns = [col for col in df_processed.columns if '_Bin_' in col]
    if len(df_processed) < lookback:
        print("lookback 데이터가 부족합니다.")
        return None
    input_seq = df_processed[final_input_columns].iloc[-lookback:]
    # 모델 입력 형태: [batch, seq_len, features]
    x = torch.tensor(input_seq.values, dtype=torch.float32).unsqueeze(0).to(device)
    with torch.no_grad():
        y_cont = model.sample(x, device)  # continuous output
        prediction = 1 if y_cont.item() >= 0.5 else 0
    return prediction

# --- 거래 함수 ---
def trade_decision():
    prediction = get_model_prediction()
    if prediction is None:
        return
    print(f"모델 예측 결과 (1: 상승, 0: 하락): {prediction}")
    if prediction == 1:
        # 상승 예측 시: 보유 KRW의 20%로 매수
        krw_balance = upbit.get_balance("KRW")
        if krw_balance is None or krw_balance < 5000:
            print("매수할 충분한 KRW 잔고가 없습니다.")
            return
        trade_amount = krw_balance * 0.5
        print(f"{ticker}을(를) {trade_amount:.0f} KRW로 매수합니다.")
        upbit.buy_market_order(ticker, trade_amount)
    else:
        # 하락 예측 시: 보유 코인의 20% 매도
        coin = ticker.split("-")[1]
        coin_balance = upbit.get_balance(coin)
        if coin_balance is None or coin_balance <= 0:
            print("매도할 보유 코인이 없습니다.")
            return
        trade_amount = coin_balance * 0.5
        print(f"{coin}의 {trade_amount:.4f}개를 매도합니다.")
        upbit.sell_market_order(ticker, trade_amount)

# --- 메인 루프: 새로운 5분봉이 생성될 때마다 업데이트 ---
last_candle_time = None
while True:
    try:
        # 최신 5분봉 데이터 1개 (마지막 봉)
        df = pyupbit.get_ohlcv(ticker, interval="minute5", count=1)
        if df is not None and not df.empty:
            current_candle_time = df.index[-1]
            # 새로운 봉이 생성되었으면 trade_decision() 실행
            if last_candle_time is None or current_candle_time > last_candle_time:
                last_candle_time = current_candle_time
                print(f"새로운 5분봉 생성: {last_candle_time}")
                trade_decision()
        else:
            print("최신 5분봉 데이터를 불러오지 못했습니다.")
    except Exception as e:
        print(f"에러 발생: {e}")
    # 10초마다 확인 (필요에 따라 sleep 시간을 조정)
    time.sleep(10)
# Out:
# 새로운 5분봉 생성: 2025-03-16 11:00:00
# 모델 예측 결과 (1: 상승, 0: 하락): 0
# 매도할 보유 코인이 없습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 187
#     185     print(f"에러 발생: {e}")
#     186 # 10초마다 확인 (필요에 따라 sleep 시간을 조정)
# --> 187 time.sleep(10)
#
# KeyboardInterrupt:

# %%
import time
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import pyupbit
import requests

# --- LINE Notify 설정 ---
TARGET_URL = 'https://notify-api.line.me/api/notify'
TOKEN = "rlMIJRZSatEVj5MLBSqC0iVVRIM7trYKqVbwizh7gUL"
def send_line_notification(message):
    headers = {
        "Authorization": f"Bearer {TOKEN}",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"message": message}
    response = requests.post(TARGET_URL, headers=headers, data=data)
    return response

def notify(message):
    print(message)
    send_line_notification(message)

# --- 전처리 함수 ---
def rolling_minmax_scale(series, window=24):
    roll_min = series.rolling(window=window, min_periods=window).min()
    roll_max = series.rolling(window=window, min_periods=window).max()
    scaled = (series - roll_min) / ((roll_max - roll_min) + 1e-8)
    scaled = scaled.replace([np.inf, -np.inf], np.nan)
    scaled = scaled.fillna(1.0)
    return scaled.clip(upper=1.0)

def bin_and_encode(data, features, bins=100, drop_original=True):
    for feature in features:
        data[f'{feature}_Bin'] = pd.cut(data[feature], bins=bins, labels=False)
        one_hot = pd.get_dummies(data[f'{feature}_Bin'], prefix=f'{feature}_Bin').astype(np.int32)
        expected_columns = [f'{feature}_Bin_{i}' for i in range(bins)]
        one_hot = one_hot.reindex(columns=expected_columns, fill_value=0)
        data = pd.concat([data, one_hot], axis=1)
        if drop_original:
            data.drop(columns=[f'{feature}_Bin'], inplace=True)
    numeric_cols = data.select_dtypes(include=[np.number]).columns.tolist()
    for col in numeric_cols:
        data[col] = data[col].astype(np.float32)
    return data

# --- Diffusion Model 구성 ---
class ConditionEncoder(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim):
        super(ConditionEncoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim * lookback, condition_dim),
            nn.ReLU(),
            nn.Linear(condition_dim, condition_dim)
        )
        
    def forward(self, x):
        # x: [batch, lookback, input_dim]
        batch_size = x.size(0)
        x = x.contiguous().view(batch_size, -1)
        return self.fc(x)

class DiffusionClassifier(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim=128, num_timesteps=100, hidden_dim=128):
        super(DiffusionClassifier, self).__init__()
        self.num_timesteps = num_timesteps
        # diffusion 스케줄 (선형 beta schedule)
        betas = torch.linspace(1e-4, 0.02, num_timesteps)
        alphas = 1 - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)
        self.register_buffer('betas', betas)
        self.register_buffer('alphas', alphas)
        self.register_buffer('alphas_cumprod', alphas_cumprod)
        
        # 조건 인코더: 시계열 window를 임베딩
        self.condition_encoder = ConditionEncoder(input_dim, lookback, condition_dim)
        # timestep 임베딩
        self.time_embedding = nn.Embedding(num_timesteps, hidden_dim)
        # 노이즈 예측 네트워크
        self.model = nn.Sequential(
            nn.Linear(1 + condition_dim + hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )
        
    def forward(self, x_condition, y_noisy, t):
        # x_condition: [batch, lookback, input_dim]
        # y_noisy: [batch, 1]
        # t: [batch]
        cond = self.condition_encoder(x_condition)           # [batch, condition_dim]
        t_emb = self.time_embedding(t)                         # [batch, hidden_dim]
        inp = torch.cat([y_noisy, cond, t_emb], dim=1)          # [batch, 1 + condition_dim + hidden_dim]
        predicted_noise = self.model(inp)                      # [batch, 1]
        return predicted_noise
    
    def sample(self, x_condition, device):
        """
        reverse diffusion 과정을 통해 조건 x_condition에 대해 예측값을 샘플링.
        최종 출력은 continuous 값으로, 임계값 0.5를 기준으로 상승(1) 또는 하락(0) 결정.
        """
        batch_size = x_condition.size(0)
        y = torch.randn(batch_size, 1, device=device)  # 초기 y: 정규분포 노이즈
        for t in reversed(range(self.num_timesteps)):
            t_tensor = torch.full((batch_size,), t, device=device, dtype=torch.long)
            predicted_noise = self.forward(x_condition, y, t_tensor)
            alpha = self.alphas[t]
            alpha_cumprod = self.alphas_cumprod[t]
            beta = self.betas[t]
            y = (1 / torch.sqrt(alpha)) * (y - (beta / torch.sqrt(1 - alpha_cumprod)) * predicted_noise)
            if t > 0:
                noise = torch.randn_like(y)
                y = y + torch.sqrt(beta) * noise
        return y

# --- 모델 로드 ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# OHLC 4개 feature를 100구간으로 binning했으므로 입력 차원은 4*100 = 400
input_dim = 400
lookback = 24
model = DiffusionClassifier(input_dim=input_dim, lookback=lookback, condition_dim=128, num_timesteps=100, hidden_dim=128).to(device)
model_path = "diffusion_model_experiment_14_24.pth"  # 실제 학습된 모델 파일 경로로 수정
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# --- pyupbit API 설정 ---
access = "x03uKM3uyZ9RNDBHLxauEaeI6X8pdKQq8rHG2wvx"
secret = "e9UyPqJBjCvNDxCmtx7bdPaHtAEgw2Ftxu3UpuJc"
upbit = pyupbit.Upbit(access, secret)
ticker = "KRW-ETH"  # 거래할 코인 티커

# --- 예측 함수 ---
def get_model_prediction():
    """
    pyupbit로 최근 15개의 5분봉 데이터를 가져와 전처리한 후,
    마지막 lookback(6) 봉을 diffusion model의 조건으로 사용하여
    reverse diffusion sampling을 통해 다음 5분봉 상승(1)/하락(0) 예측을 반환.
    """
    df = pyupbit.get_ohlcv(ticker, interval="minute5", count=50)
    if df is None or len(df) < lookback:
        notify("예측에 충분한 데이터가 없습니다.")
        return None
    ohlc_features = ['open', 'high', 'low', 'close']
    for feature in ohlc_features:
        df[feature] = rolling_minmax_scale(df[feature], window=24)
    df_processed = bin_and_encode(df.copy(), ohlc_features, bins=100, drop_original=True)
    final_input_columns = [col for col in df_processed.columns if '_Bin_' in col]
    if len(df_processed) < lookback:
        notify("lookback 데이터가 부족합니다.")
        return None
    input_seq = df_processed[final_input_columns].iloc[-lookback:]
    # 모델 입력 형태: [batch, seq_len, features]
    x = torch.tensor(input_seq.values, dtype=torch.float32).unsqueeze(0).to(device)
    with torch.no_grad():
        y_cont = model.sample(x, device)  # continuous output
        notify("디버그: y_cont = " + str(y_cont.item()))
        prediction = 1 if y_cont.item() >= 0.5 else 0
    return prediction

# --- 글로벌 변수: pending_trade와 거래 통계 ---
pending_trade = None  # 현재 진행 중인 거래 정보 저장 (없으면 None)
stats = {
    'total_trades': 0,
    'win_count': 0,
    'cumulative_return': 1.0,
    'trade_returns': []
}

# --- 거래 실행 함수 (신규 거래 진입) ---
def trade_decision():
    global pending_trade
    prediction = get_model_prediction()
    if prediction is None:
        return
    entry_price = pyupbit.get_current_price(ticker)
    if entry_price is None:
        notify("현재가를 조회하지 못했습니다.")
        return
    if prediction == 1:
        # 상승 예측: KRW 잔고의 50% 사용하여 매수 → 구매 코인 수 = (거래금액 / 진입가)
        krw_balance = upbit.get_balance("KRW")
        if krw_balance is None or krw_balance < 5000:
            notify("매수할 충분한 KRW 잔고가 없습니다.")
            return
        trade_amount_krw = krw_balance * 0.2
        coins_bought = trade_amount_krw / entry_price
        notify(f"[진입] 상승 예측: KRW 잔고의 50%({trade_amount_krw:.0f} KRW)로 매수, 진입가: {entry_price:.2f}, 구매 개수: {coins_bought:.4f} 개")
        upbit.buy_market_order(ticker, trade_amount_krw)  # 실제 주문 실행 (주석 해제)
        pending_trade = {
            'direction': prediction,  # 1: Long
            'entry_price': entry_price,
            'quantity': coins_bought,
            'entry_time': pd.Timestamp.now()
        }
    else:
        # 하락 예측: 보유 코인의 50% 매도
        coin = ticker.split("-")[1]
        coin_balance = upbit.get_balance(coin)
        if coin_balance is None or coin_balance <= 0:
            notify("매도할 보유 코인이 없습니다.")
            return
        trade_amount_coins = coin_balance * 0.2
        notify(f"[진입] 하락 예측: 보유 코인의 50%({trade_amount_coins:.4f} 개) 매도, 진입가: {entry_price:.2f}")
        upbit.sell_market_order(ticker, trade_amount_coins)  # 실제 주문 실행 (주석 해제)
        pending_trade = {
            'direction': prediction,  # 0: Short
            'entry_price': entry_price,
            'quantity': trade_amount_coins,
            'entry_time': pd.Timestamp.now()
        }

# --- 거래 결과 처리 함수 (청산 시점에서 거래 결과 계산) ---
def process_pending_trade():
    global pending_trade, stats
    if pending_trade is None:
        return
    exit_price = pyupbit.get_current_price(ticker)
    if exit_price is None:
        notify("청산 가격을 조회하지 못했습니다.")
        return
    direction = pending_trade['direction']
    entry_price = pending_trade['entry_price']
    fee = 0.0005  # 0.05%
    if direction == 1:  # Long 거래: 상승 예측
        fraction = 0.2
        effective_factor = (exit_price * (1 - fee)) / (entry_price * (1 + fee))
        trade_return = 1 + fraction * (effective_factor - 1)
        trade_type = "Long"
        # hit/miss 판정: Long 거래는 exit_price가 entry_price보다 높아야 hit
        outcome = "Hit" if exit_price > entry_price else "Miss"
    else:  # Short 거래: 하락 예측
        fraction = 0.2
        effective_factor = (entry_price * (1 - fee)) / (exit_price * (1 + fee))
        trade_return = 1 + fraction * (effective_factor - 1)
        trade_type = "Short"
        # hit/miss 판정: Short 거래는 exit_price가 entry_price보다 같거나 낮아야 hit (보합 포함)
        outcome = "Hit" if exit_price <= entry_price else "Miss"
    
    stats['total_trades'] += 1
    if outcome == "Hit":
        stats['win_count'] += 1
    stats['cumulative_return'] *= trade_return
    stats['trade_returns'].append(trade_return)
    quantity = pending_trade.get('quantity', 0)
    notify(f"[청산] {trade_type} 거래 - 진입가: {entry_price:.2f}, 청산가: {exit_price:.2f}, 거래 개수: {quantity:.4f} 개, 거래 수익률: {trade_return:.4f} ({outcome})")
    hit_ratio = stats['win_count'] / stats['total_trades'] if stats['total_trades'] > 0 else 0
    notify(f"거래 횟수: {stats['total_trades']}, Hit Ratio: {hit_ratio:.2%}, 누적 수익률: {stats['cumulative_return']:.4f}\n")
    pending_trade = None

# --- 메인 루프: 새로운 5분봉이 생성될 때마다 업데이트 ---
last_candle_time = None
while True:
    try:
        df = pyupbit.get_ohlcv(ticker, interval="minute5", count=1)
        if df is not None and not df.empty:
            current_candle_time = df.index[-1]
            if last_candle_time is None or current_candle_time > last_candle_time:
                if pending_trade is not None:
                    process_pending_trade()
                notify(f"새로운 5분봉 생성: {current_candle_time}")
                trade_decision()
                last_candle_time = current_candle_time
        else:
            notify("최신 5분봉 데이터를 불러오지 못했습니다.")
    except Exception as e:
        notify(f"에러 발생: {e}")
    time.sleep(10)
# Out:
# 새로운 5분봉 생성: 2025-03-17 19:15:00
# 디버그: y_cont = 1.0597153902053833
# [진입] 상승 예측: KRW 잔고의 50%(9713 KRW)로 매수, 진입가: 2795000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2795000.00, 청산가: 2795000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 1, Hit Ratio: 0.00%, 누적 수익률: 0.9998
#
# 새로운 5분봉 생성: 2025-03-17 19:20:00
# 디버그: y_cont = 1.0082778930664062
# [진입] 상승 예측: KRW 잔고의 50%(7769 KRW)로 매수, 진입가: 2795000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2795000.00, 청산가: 2803000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0004 (Hit)
# 거래 횟수: 2, Hit Ratio: 50.00%, 누적 수익률: 1.0002
#
# 새로운 5분봉 생성: 2025-03-17 19:25:00
# 디버그: y_cont = 0.005496538709849119
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2803000.00
# [청산] Short 거래 - 진입가: 2803000.00, 청산가: 2800000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 3, Hit Ratio: 66.67%, 누적 수익률: 1.0002
#
# 새로운 5분봉 생성: 2025-03-17 19:30:00
# 디버그: y_cont = 0.967979371547699
# [진입] 상승 예측: KRW 잔고의 50%(7794 KRW)로 매수, 진입가: 2800000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2800000.00, 청산가: 2799000.00, 거래 개수: 0.0028 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 4, Hit Ratio: 50.00%, 누적 수익률: 0.9999
#
# 새로운 5분봉 생성: 2025-03-17 19:35:00
# 디버그: y_cont = -0.0043704928830266
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2799000.00
# [청산] Short 거래 - 진입가: 2799000.00, 청산가: 2800000.00, 거래 개수: 0.0028 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 5, Hit Ratio: 40.00%, 누적 수익률: 0.9996
#
# 새로운 5분봉 생성: 2025-03-17 19:40:00
# 디버그: y_cont = 0.9753891825675964
# [진입] 상승 예측: KRW 잔고의 50%(7806 KRW)로 매수, 진입가: 2800000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2800000.00, 청산가: 2804000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 6, Hit Ratio: 50.00%, 누적 수익률: 0.9997
#
# 새로운 5분봉 생성: 2025-03-17 19:45:00
# 디버그: y_cont = 0.04963931813836098
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2804000.00
# [청산] Short 거래 - 진입가: 2804000.00, 청산가: 2801000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 7, Hit Ratio: 57.14%, 누적 수익률: 0.9997
#
# 새로운 5분봉 생성: 2025-03-17 19:50:00
# 디버그: y_cont = 0.030604150146245956
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2801000.00
# [청산] Short 거래 - 진입가: 2801000.00, 청산가: 2802000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 8, Hit Ratio: 50.00%, 누적 수익률: 0.9995
#
# 새로운 5분봉 생성: 2025-03-17 19:55:00
# 디버그: y_cont = 0.01544107310473919
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2802000.00
# [청산] Short 거래 - 진입가: 2802000.00, 청산가: 2802000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 9, Hit Ratio: 55.56%, 누적 수익률: 0.9993
#
# 새로운 5분봉 생성: 2025-03-17 20:00:00
# 디버그: y_cont = 0.006386604625731707
# [진입] 하락 예측: 보유 코인의 50%(0.0014 개) 매도, 진입가: 2802000.00
# [청산] Short 거래 - 진입가: 2802000.00, 청산가: 2799000.00, 거래 개수: 0.0014 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 10, Hit Ratio: 60.00%, 누적 수익률: 0.9993
#
# 새로운 5분봉 생성: 2025-03-17 20:05:00
# 디버그: y_cont = 0.9550173282623291
# [진입] 상승 예측: KRW 잔고의 50%(10078 KRW)로 매수, 진입가: 2799000.00, 구매 개수: 0.0036 개
# [청산] Long 거래 - 진입가: 2799000.00, 청산가: 2799000.00, 거래 개수: 0.0036 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 11, Hit Ratio: 54.55%, 누적 수익률: 0.9991
#
# 새로운 5분봉 생성: 2025-03-17 20:10:00
# 디버그: y_cont = 0.9967968463897705
# [진입] 상승 예측: KRW 잔고의 50%(8061 KRW)로 매수, 진입가: 2799000.00, 구매 개수: 0.0029 개
# [청산] Long 거래 - 진입가: 2799000.00, 청산가: 2799000.00, 거래 개수: 0.0029 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 12, Hit Ratio: 50.00%, 누적 수익률: 0.9989
#
# 새로운 5분봉 생성: 2025-03-17 20:15:00
# 디버그: y_cont = 0.9727346301078796
# [진입] 상승 예측: KRW 잔고의 50%(6448 KRW)로 매수, 진입가: 2800000.00, 구매 개수: 0.0023 개
# [청산] Long 거래 - 진입가: 2800000.00, 청산가: 2808000.00, 거래 개수: 0.0023 개, 거래 수익률: 1.0004 (Hit)
# 거래 횟수: 13, Hit Ratio: 53.85%, 누적 수익률: 0.9993
#
# 새로운 5분봉 생성: 2025-03-17 20:20:00
# 디버그: y_cont = -0.00323228701017797
# [진입] 하락 예측: 보유 코인의 50%(0.0032 개) 매도, 진입가: 2808000.00
# [청산] Short 거래 - 진입가: 2808000.00, 청산가: 2808000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 14, Hit Ratio: 57.14%, 누적 수익률: 0.9991
#
# 새로운 5분봉 생성: 2025-03-17 20:25:00
# 디버그: y_cont = -0.0028413960244506598
# [진입] 하락 예측: 보유 코인의 50%(0.0026 개) 매도, 진입가: 2808000.00
# [청산] Short 거래 - 진입가: 2808000.00, 청산가: 2807000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 15, Hit Ratio: 60.00%, 누적 수익률: 0.9989
#
# 새로운 5분봉 생성: 2025-03-17 20:30:00
# 디버그: y_cont = -0.007967779412865639
# [진입] 하락 예측: 보유 코인의 50%(0.0020 개) 매도, 진입가: 2807000.00
# [청산] Short 거래 - 진입가: 2807000.00, 청산가: 2804000.00, 거래 개수: 0.0020 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 16, Hit Ratio: 62.50%, 누적 수익률: 0.9989
#
# 새로운 5분봉 생성: 2025-03-17 20:35:00
# 디버그: y_cont = 0.018726198002696037
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2804000.00
# [청산] Short 거래 - 진입가: 2804000.00, 청산가: 2806000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 17, Hit Ratio: 58.82%, 누적 수익률: 0.9986
#
# 새로운 5분봉 생성: 2025-03-17 20:40:00
# 디버그: y_cont = 1.021996021270752
# [진입] 상승 예측: KRW 잔고의 50%(9528 KRW)로 매수, 진입가: 2806000.00, 구매 개수: 0.0034 개
# [청산] Long 거래 - 진입가: 2806000.00, 청산가: 2803000.00, 거래 개수: 0.0034 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 18, Hit Ratio: 55.56%, 누적 수익률: 0.9982
#
# 새로운 5분봉 생성: 2025-03-17 20:45:00
# 디버그: y_cont = 1.0307549238204956
# [진입] 상승 예측: KRW 잔고의 50%(7622 KRW)로 매수, 진입가: 2803000.00, 구매 개수: 0.0027 개
# [청산] Long 거래 - 진입가: 2803000.00, 청산가: 2803000.00, 거래 개수: 0.0027 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 19, Hit Ratio: 52.63%, 누적 수익률: 0.9980
#
# 새로운 5분봉 생성: 2025-03-17 20:50:00
# 디버그: y_cont = 0.9601258039474487
# [진입] 상승 예측: KRW 잔고의 50%(6097 KRW)로 매수, 진입가: 2803000.00, 구매 개수: 0.0022 개
# [청산] Long 거래 - 진입가: 2803000.00, 청산가: 2802000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 20, Hit Ratio: 50.00%, 누적 수익률: 0.9977
#
# 새로운 5분봉 생성: 2025-03-17 20:55:00
# 디버그: y_cont = 1.0006331205368042
# [진입] 상승 예측: KRW 잔고의 50%(4877 KRW)로 매수, 진입가: 2802000.00, 구매 개수: 0.0017 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2802000.00, 청산가: 2804000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 21, Hit Ratio: 52.38%, 누적 수익률: 0.9977
#
# 새로운 5분봉 생성: 2025-03-17 21:00:00
# 디버그: y_cont = -0.005760000552982092
# [진입] 하락 예측: 보유 코인의 50%(0.0033 개) 매도, 진입가: 2804000.00
# [청산] Short 거래 - 진입가: 2804000.00, 청산가: 2803000.00, 거래 개수: 0.0033 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 22, Hit Ratio: 54.55%, 누적 수익률: 0.9975
#
# 새로운 5분봉 생성: 2025-03-17 21:05:00
# 디버그: y_cont = 0.922299325466156
# [진입] 상승 예측: KRW 잔고의 50%(6720 KRW)로 매수, 진입가: 2803000.00, 구매 개수: 0.0024 개
# [청산] Long 거래 - 진입가: 2803000.00, 청산가: 2800000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 23, Hit Ratio: 52.17%, 누적 수익률: 0.9971
#
# 새로운 5분봉 생성: 2025-03-17 21:10:00
# 디버그: y_cont = 0.9671865105628967
# [진입] 상승 예측: KRW 잔고의 50%(5375 KRW)로 매수, 진입가: 2800000.00, 구매 개수: 0.0019 개
# [청산] Long 거래 - 진입가: 2800000.00, 청산가: 2796000.00, 거래 개수: 0.0019 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 24, Hit Ratio: 50.00%, 누적 수익률: 0.9966
#
# 새로운 5분봉 생성: 2025-03-17 21:15:00
# 디버그: y_cont = 0.01908792555332184
# [진입] 하락 예측: 보유 코인의 50%(0.0035 개) 매도, 진입가: 2796000.00
# [청산] Short 거래 - 진입가: 2796000.00, 청산가: 2795000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 25, Hit Ratio: 52.00%, 누적 수익률: 0.9965
#
# 새로운 5분봉 생성: 2025-03-17 21:20:00
# 디버그: y_cont = 0.9952054619789124
# [진입] 상승 예측: KRW 잔고의 50%(6254 KRW)로 매수, 진입가: 2795000.00, 구매 개수: 0.0022 개
# [청산] Long 거래 - 진입가: 2795000.00, 청산가: 2797000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 26, Hit Ratio: 53.85%, 누적 수익률: 0.9965
#
# 새로운 5분봉 생성: 2025-03-17 21:25:00
# 디버그: y_cont = -0.03147117421030998
# [진입] 하락 예측: 보유 코인의 50%(0.0032 개) 매도, 진입가: 2797000.00
# [청산] Short 거래 - 진입가: 2797000.00, 청산가: 2797000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 27, Hit Ratio: 55.56%, 누적 수익률: 0.9963
#
# 새로운 5분봉 생성: 2025-03-17 21:30:00
# 디버그: y_cont = 1.0193334817886353
# [진입] 상승 예측: KRW 잔고의 50%(6816 KRW)로 매수, 진입가: 2797000.00, 구매 개수: 0.0024 개
# [청산] Long 거래 - 진입가: 2797000.00, 청산가: 2812000.00, 거래 개수: 0.0024 개, 거래 수익률: 1.0009 (Hit)
# 거래 횟수: 28, Hit Ratio: 57.14%, 누적 수익률: 0.9971
#
# 새로운 5분봉 생성: 2025-03-17 21:35:00
# 디버그: y_cont = 0.015720916911959648
# [진입] 하락 예측: 보유 코인의 50%(0.0031 개) 매도, 진입가: 2812000.00
# [청산] Short 거래 - 진입가: 2812000.00, 청산가: 2802000.00, 거래 개수: 0.0031 개, 거래 수익률: 1.0005 (Hit)
# 거래 횟수: 29, Hit Ratio: 58.62%, 누적 수익률: 0.9976
#
# 새로운 5분봉 생성: 2025-03-17 21:40:00
# 디버그: y_cont = 0.012061738409101963
# [진입] 하락 예측: 보유 코인의 50%(0.0025 개) 매도, 진입가: 2802000.00
# [청산] Short 거래 - 진입가: 2802000.00, 청산가: 2803000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 30, Hit Ratio: 56.67%, 누적 수익률: 0.9974
#
# 새로운 5분봉 생성: 2025-03-17 21:45:00
# 디버그: y_cont = -0.009135844185948372
# [진입] 하락 예측: 보유 코인의 50%(0.0020 개) 매도, 진입가: 2802000.00
# [청산] Short 거래 - 진입가: 2802000.00, 청산가: 2801000.00, 거래 개수: 0.0020 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 31, Hit Ratio: 58.06%, 누적 수익률: 0.9972
#
# 새로운 5분봉 생성: 2025-03-17 21:50:00
# 디버그: y_cont = 0.008383533917367458
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2801000.00
# [청산] Short 거래 - 진입가: 2801000.00, 청산가: 2794000.00, 거래 개수: 0.0016 개, 거래 수익률: 1.0003 (Hit)
# 거래 횟수: 32, Hit Ratio: 59.38%, 누적 수익률: 0.9975
#
# 새로운 5분봉 생성: 2025-03-17 21:55:00
# 디버그: y_cont = 0.9845883250236511
# [진입] 상승 예측: KRW 잔고의 50%(9671 KRW)로 매수, 진입가: 2794000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2794000.00, 청산가: 2799000.00, 거래 개수: 0.0035 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 33, Hit Ratio: 60.61%, 누적 수익률: 0.9977
#
# 새로운 5분봉 생성: 2025-03-17 22:00:00
# 디버그: y_cont = 0.004017229191958904
# [진입] 하락 예측: 보유 코인의 50%(0.0023 개) 매도, 진입가: 2799000.00
# [청산] Short 거래 - 진입가: 2799000.00, 청산가: 2792000.00, 거래 개수: 0.0023 개, 거래 수익률: 1.0003 (Hit)
# 거래 횟수: 34, Hit Ratio: 61.76%, 누적 수익률: 0.9980
#
# 새로운 5분봉 생성: 2025-03-17 22:05:00
# 디버그: y_cont = 0.9698117971420288
# [진입] 상승 예측: KRW 잔고의 50%(9005 KRW)로 매수, 진입가: 2792000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2792000.00, 청산가: 2796000.00, 거래 개수: 0.0032 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 35, Hit Ratio: 62.86%, 누적 수익률: 0.9981
#
# 새로운 5분봉 생성: 2025-03-17 22:10:00
# 디버그: y_cont = 0.05153351277112961
# [진입] 하락 예측: 보유 코인의 50%(0.0025 개) 매도, 진입가: 2796000.00
# [청산] Short 거래 - 진입가: 2796000.00, 청산가: 2793000.00, 거래 개수: 0.0025 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 36, Hit Ratio: 63.89%, 누적 수익률: 0.9981
#
# 새로운 5분봉 생성: 2025-03-17 22:15:00
# 디버그: y_cont = 1.0252944231033325
# [진입] 상승 예측: KRW 잔고의 50%(8579 KRW)로 매수, 진입가: 2793000.00, 구매 개수: 0.0031 개
# [청산] Long 거래 - 진입가: 2793000.00, 청산가: 2789000.00, 거래 개수: 0.0031 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 37, Hit Ratio: 62.16%, 누적 수익률: 0.9976
#
# 새로운 5분봉 생성: 2025-03-17 22:20:00
# 디버그: y_cont = 1.0092344284057617
# [진입] 상승 예측: KRW 잔고의 50%(6863 KRW)로 매수, 진입가: 2789000.00, 구매 개수: 0.0025 개
# [청산] Long 거래 - 진입가: 2789000.00, 청산가: 2788000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 38, Hit Ratio: 60.53%, 누적 수익률: 0.9973
#
# 새로운 5분봉 생성: 2025-03-17 22:25:00
# 디버그: y_cont = -0.008815640583634377
# [진입] 하락 예측: 보유 코인의 50%(0.0031 개) 매도, 진입가: 2788000.00
# [청산] Short 거래 - 진입가: 2788000.00, 청산가: 2784000.00, 거래 개수: 0.0031 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 39, Hit Ratio: 61.54%, 누적 수익률: 0.9974
#
# 새로운 5분봉 생성: 2025-03-17 22:30:00
# 디버그: y_cont = 0.018639013171195984
# [진입] 하락 예측: 보유 코인의 50%(0.0025 개) 매도, 진입가: 2784000.00
# [청산] Short 거래 - 진입가: 2784000.00, 청산가: 2793000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9992 (Miss)
# 거래 횟수: 40, Hit Ratio: 60.00%, 누적 수익률: 0.9966
#
# 새로운 5분봉 생성: 2025-03-17 22:35:00
# 디버그: y_cont = 0.9554674029350281
# [진입] 상승 예측: KRW 잔고의 50%(8572 KRW)로 매수, 진입가: 2793000.00, 구매 개수: 0.0031 개
# [청산] Long 거래 - 진입가: 2793000.00, 청산가: 2804000.00, 거래 개수: 0.0031 개, 거래 수익률: 1.0006 (Hit)
# 거래 횟수: 41, Hit Ratio: 60.98%, 누적 수익률: 0.9972
#
# 새로운 5분봉 생성: 2025-03-17 22:40:00
# 디버그: y_cont = 0.04518478363752365
# [진입] 하락 예측: 보유 코인의 50%(0.0026 개) 매도, 진입가: 2804000.00
# [청산] Short 거래 - 진입가: 2804000.00, 청산가: 2798000.00, 거래 개수: 0.0026 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 42, Hit Ratio: 61.90%, 누적 수익률: 0.9974
#
# 새로운 5분봉 생성: 2025-03-17 22:45:00
# 디버그: y_cont = 0.964816689491272
# [진입] 상승 예측: KRW 잔고의 50%(8304 KRW)로 매수, 진입가: 2800000.00, 구매 개수: 0.0030 개
# [청산] Long 거래 - 진입가: 2800000.00, 청산가: 2785000.00, 거래 개수: 0.0030 개, 거래 수익률: 0.9987 (Miss)
# 거래 횟수: 43, Hit Ratio: 60.47%, 누적 수익률: 0.9961
#
# 새로운 5분봉 생성: 2025-03-17 22:50:00
# 디버그: y_cont = 0.006688409019261599
# [진입] 하락 예측: 보유 코인의 50%(0.0027 개) 매도, 진입가: 2785000.00
# [청산] Short 거래 - 진입가: 2785000.00, 청산가: 2793000.00, 거래 개수: 0.0027 개, 거래 수익률: 0.9992 (Miss)
# 거래 횟수: 44, Hit Ratio: 59.09%, 누적 수익률: 0.9954
#
# 새로운 5분봉 생성: 2025-03-17 22:55:00
# 디버그: y_cont = 0.03070049174129963
# [진입] 하락 예측: 보유 코인의 50%(0.0021 개) 매도, 진입가: 2793000.00
# [청산] Short 거래 - 진입가: 2793000.00, 청산가: 2788000.00, 거래 개수: 0.0021 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 45, Hit Ratio: 60.00%, 누적 수익률: 0.9955
#
# 새로운 5분봉 생성: 2025-03-17 23:00:00
# 디버그: y_cont = 0.0011813766323029995
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2788000.00
# [청산] Short 거래 - 진입가: 2788000.00, 청산가: 2783000.00, 거래 개수: 0.0017 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 46, Hit Ratio: 60.87%, 누적 수익률: 0.9957
#
# 새로운 5분봉 생성: 2025-03-17 23:05:00
# 디버그: y_cont = 1.00226891040802
# [진입] 상승 예측: KRW 잔고의 50%(9309 KRW)로 매수, 진입가: 2785000.00, 구매 개수: 0.0033 개
# [청산] Long 거래 - 진입가: 2785000.00, 청산가: 2783000.00, 거래 개수: 0.0033 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 47, Hit Ratio: 59.57%, 누적 수익률: 0.9953
#
# 새로운 5분봉 생성: 2025-03-17 23:10:00
# 디버그: y_cont = 0.028935132548213005
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2783000.00
# [청산] Short 거래 - 진입가: 2783000.00, 청산가: 2787000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 48, Hit Ratio: 58.33%, 누적 수익률: 0.9948
#
# 새로운 5분봉 생성: 2025-03-17 23:15:00
# 디버그: y_cont = 0.008280823938548565
# [진입] 하락 예측: 보유 코인의 50%(0.0019 개) 매도, 진입가: 2787000.00
# [청산] Short 거래 - 진입가: 2787000.00, 청산가: 2783000.00, 거래 개수: 0.0019 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 49, Hit Ratio: 59.18%, 누적 수익률: 0.9949
#
# 새로운 5분봉 생성: 2025-03-17 23:20:00
# 디버그: y_cont = 0.005618711467832327
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2783000.00
# [청산] Short 거래 - 진입가: 2783000.00, 청산가: 2787000.00, 거래 개수: 0.0015 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 50, Hit Ratio: 58.00%, 누적 수익률: 0.9945
#
# 새로운 5분봉 생성: 2025-03-17 23:25:00
# 디버그: y_cont = -0.012240990996360779
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2788000.00
# [청산] Short 거래 - 진입가: 2788000.00, 청산가: 2785000.00, 거래 개수: 0.0015 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 51, Hit Ratio: 58.82%, 누적 수익률: 0.9945
#
# 새로운 5분봉 생성: 2025-03-17 23:30:00
# 디버그: y_cont = 1.0124874114990234
# [진입] 상승 예측: KRW 잔고의 50%(9820 KRW)로 매수, 진입가: 2785000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2785000.00, 청산가: 2790000.00, 거래 개수: 0.0035 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 52, Hit Ratio: 59.62%, 누적 수익률: 0.9946
#
# 새로운 5분봉 생성: 2025-03-17 23:35:00
# 디버그: y_cont = 0.976945698261261
# [진입] 상승 예측: KRW 잔고의 50%(7855 KRW)로 매수, 진입가: 2790000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2790000.00, 청산가: 2798000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0004 (Hit)
# 거래 횟수: 53, Hit Ratio: 60.38%, 누적 수익률: 0.9950
#
# 새로운 5분봉 생성: 2025-03-17 23:40:00
# 디버그: y_cont = 1.002683162689209
# [진입] 상승 예측: KRW 잔고의 50%(6283 KRW)로 매수, 진입가: 2798000.00, 구매 개수: 0.0022 개
# [청산] Long 거래 - 진입가: 2798000.00, 청산가: 2799000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 54, Hit Ratio: 61.11%, 누적 수익률: 0.9949
#
# 새로운 5분봉 생성: 2025-03-17 23:45:00
# 디버그: y_cont = 0.020262211561203003
# [진입] 하락 예측: 보유 코인의 50%(0.0032 개) 매도, 진입가: 2799000.00
# [청산] Short 거래 - 진입가: 2799000.00, 청산가: 2800000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 55, Hit Ratio: 60.00%, 누적 수익률: 0.9946
#
# 새로운 5분봉 생성: 2025-03-17 23:50:00
# 디버그: y_cont = 0.006786264479160309
# [진입] 하락 예측: 보유 코인의 50%(0.0026 개) 매도, 진입가: 2800000.00
# [청산] Short 거래 - 진입가: 2800000.00, 청산가: 2791000.00, 거래 개수: 0.0026 개, 거래 수익률: 1.0004 (Hit)
# 거래 횟수: 56, Hit Ratio: 60.71%, 누적 수익률: 0.9950
#
# 새로운 5분봉 생성: 2025-03-17 23:55:00
# 디버그: y_cont = 1.0365216732025146
# [진입] 상승 예측: KRW 잔고의 50%(8282 KRW)로 매수, 진입가: 2790000.00, 구매 개수: 0.0030 개
# [청산] Long 거래 - 진입가: 2790000.00, 청산가: 2784000.00, 거래 개수: 0.0030 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 57, Hit Ratio: 59.65%, 누적 수익률: 0.9944
#
# 새로운 5분봉 생성: 2025-03-18 00:00:00
# 디버그: y_cont = -0.0004406438092701137
# [진입] 하락 예측: 보유 코인의 50%(0.0027 개) 매도, 진입가: 2784000.00
# [청산] Short 거래 - 진입가: 2784000.00, 청산가: 2782000.00, 거래 개수: 0.0027 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 58, Hit Ratio: 60.34%, 누적 수익률: 0.9944
#
# 새로운 5분봉 생성: 2025-03-18 00:05:00
# 디버그: y_cont = 0.010075952857732773
# [진입] 하락 예측: 보유 코인의 50%(0.0021 개) 매도, 진입가: 2782000.00
# [청산] Short 거래 - 진입가: 2782000.00, 청산가: 2792000.00, 거래 개수: 0.0021 개, 거래 수익률: 0.9991 (Miss)
# 거래 횟수: 59, Hit Ratio: 59.32%, 누적 수익률: 0.9934
#
# 새로운 5분봉 생성: 2025-03-18 00:10:00
# 디버그: y_cont = 0.9325621128082275
# [진입] 상승 예측: KRW 잔고의 50%(9289 KRW)로 매수, 진입가: 2792000.00, 구매 개수: 0.0033 개
# [청산] Long 거래 - 진입가: 2792000.00, 청산가: 2797000.00, 거래 개수: 0.0033 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 60, Hit Ratio: 60.00%, 누적 수익률: 0.9936
#
# 새로운 5분봉 생성: 2025-03-18 00:15:00
# 디버그: y_cont = -0.06941302120685577
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2797000.00
# [청산] Short 거래 - 진입가: 2797000.00, 청산가: 2802000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 61, Hit Ratio: 59.02%, 누적 수익률: 0.9930
#
# 새로운 5분봉 생성: 2025-03-18 00:20:00
# 디버그: y_cont = 0.9909290671348572
# [진입] 상승 예측: KRW 잔고의 50%(8754 KRW)로 매수, 진입가: 2802000.00, 구매 개수: 0.0031 개
# [청산] Long 거래 - 진입가: 2802000.00, 청산가: 2802000.00, 거래 개수: 0.0031 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 62, Hit Ratio: 58.06%, 누적 수익률: 0.9929
#
# 새로운 5분봉 생성: 2025-03-18 00:25:00
# 디버그: y_cont = 0.9278175830841064
# [진입] 상승 예측: KRW 잔고의 50%(7002 KRW)로 매수, 진입가: 2802000.00, 구매 개수: 0.0025 개
# [청산] Long 거래 - 진입가: 2802000.00, 청산가: 2802000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 63, Hit Ratio: 57.14%, 누적 수익률: 0.9927
#
# 새로운 5분봉 생성: 2025-03-18 00:30:00
# 디버그: y_cont = 0.02488967962563038
# [진입] 하락 예측: 보유 코인의 50%(0.0030 개) 매도, 진입가: 2802000.00
# [청산] Short 거래 - 진입가: 2802000.00, 청산가: 2796000.00, 거래 개수: 0.0030 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 64, Hit Ratio: 57.81%, 누적 수익률: 0.9929
#
# 새로운 5분봉 생성: 2025-03-18 00:35:00
# 디버그: y_cont = 0.029570920392870903
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2796000.00
# [청산] Short 거래 - 진입가: 2796000.00, 청산가: 2801000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 65, Hit Ratio: 56.92%, 누적 수익률: 0.9923
#
# 새로운 5분봉 생성: 2025-03-18 00:40:00
# 디버그: y_cont = 0.01559445634484291
# [진입] 하락 예측: 보유 코인의 50%(0.0019 개) 매도, 진입가: 2801000.00
# [청산] Short 거래 - 진입가: 2801000.00, 청산가: 2803000.00, 거래 개수: 0.0019 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 66, Hit Ratio: 56.06%, 누적 수익률: 0.9920
#
# 새로운 5분봉 생성: 2025-03-18 00:45:00
# 디버그: y_cont = 0.02721153013408184
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2803000.00
# [청산] Short 거래 - 진입가: 2803000.00, 청산가: 2803000.00, 거래 개수: 0.0015 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 67, Hit Ratio: 56.72%, 누적 수익률: 0.9918
#
# 새로운 5분봉 생성: 2025-03-18 00:50:00
# 디버그: y_cont = -0.0032630260102450848
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2803000.00
# [청산] Short 거래 - 진입가: 2803000.00, 청산가: 2815000.00, 거래 개수: 0.0015 개, 거래 수익률: 0.9989 (Miss)
# 거래 횟수: 68, Hit Ratio: 55.88%, 누적 수익률: 0.9907
#
# 새로운 5분봉 생성: 2025-03-18 00:55:00
# 디버그: y_cont = 0.0037832525558769703
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2815000.00
# [청산] Short 거래 - 진입가: 2815000.00, 청산가: 2809000.00, 거래 개수: 0.0015 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 69, Hit Ratio: 56.52%, 누적 수익률: 0.9910
#
# 새로운 5분봉 생성: 2025-03-18 01:00:00
# 디버그: y_cont = 1.0150905847549438
# [진입] 상승 예측: KRW 잔고의 50%(9724 KRW)로 매수, 진입가: 2809000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2809000.00, 청산가: 2811000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 70, Hit Ratio: 57.14%, 누적 수익률: 0.9909
#
# 새로운 5분봉 생성: 2025-03-18 01:05:00
# 디버그: y_cont = 1.0301767587661743
# [진입] 상승 예측: KRW 잔고의 50%(7778 KRW)로 매수, 진입가: 2810000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2810000.00, 청산가: 2815000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 71, Hit Ratio: 57.75%, 누적 수익률: 0.9911
#
# 새로운 5분봉 생성: 2025-03-18 01:10:00
# 디버그: y_cont = -0.010358067229390144
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2816000.00
# [청산] Short 거래 - 진입가: 2816000.00, 청산가: 2813000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 72, Hit Ratio: 58.33%, 누적 수익률: 0.9911
#
# 새로운 5분봉 생성: 2025-03-18 01:15:00
# 디버그: y_cont = 0.03517615422606468
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2813000.00
# [청산] Short 거래 - 진입가: 2813000.00, 청산가: 2811000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 73, Hit Ratio: 58.90%, 누적 수익률: 0.9910
#
# 새로운 5분봉 생성: 2025-03-18 01:20:00
# 디버그: y_cont = 0.9750369191169739
# [진입] 상승 예측: KRW 잔고의 50%(9047 KRW)로 매수, 진입가: 2811000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2811000.00, 청산가: 2805000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 74, Hit Ratio: 58.11%, 누적 수익률: 0.9904
#
# 새로운 5분봉 생성: 2025-03-18 01:25:00
# 디버그: y_cont = 0.0739879161119461
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2805000.00
# [청산] Short 거래 - 진입가: 2805000.00, 청산가: 2805000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 75, Hit Ratio: 58.67%, 누적 수익률: 0.9902
#
# 새로운 5분봉 생성: 2025-03-18 01:30:00
# 디버그: y_cont = 0.9964503049850464
# [진입] 상승 예측: KRW 잔고의 50%(8598 KRW)로 매수, 진입가: 2805000.00, 구매 개수: 0.0031 개
# [청산] Long 거래 - 진입가: 2805000.00, 청산가: 2803000.00, 거래 개수: 0.0031 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 76, Hit Ratio: 57.89%, 누적 수익률: 0.9899
#
# 새로운 5분봉 생성: 2025-03-18 01:35:00
# 디버그: y_cont = 0.0016897664172574878
# [진입] 하락 예측: 보유 코인의 50%(0.0026 개) 매도, 진입가: 2803000.00
# [청산] Short 거래 - 진입가: 2803000.00, 청산가: 2799000.00, 거래 개수: 0.0026 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 77, Hit Ratio: 58.44%, 누적 수익률: 0.9900
#
# 새로운 5분봉 생성: 2025-03-18 01:40:00
# 디버그: y_cont = -0.011719227768480778
# [진입] 하락 예측: 보유 코인의 50%(0.0020 개) 매도, 진입가: 2799000.00
# [청산] Short 거래 - 진입가: 2799000.00, 청산가: 2796000.00, 거래 개수: 0.0020 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 78, Hit Ratio: 58.97%, 누적 수익률: 0.9900
#
# 새로운 5분봉 생성: 2025-03-18 01:45:00
# 디버그: y_cont = -0.01169220358133316
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2796000.00
# [청산] Short 거래 - 진입가: 2796000.00, 청산가: 2799000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 79, Hit Ratio: 58.23%, 누적 수익률: 0.9896
#
# 새로운 5분봉 생성: 2025-03-18 01:50:00
# 디버그: y_cont = -0.014941724948585033
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2799000.00
# [청산] Short 거래 - 진입가: 2799000.00, 청산가: 2802000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 80, Hit Ratio: 57.50%, 누적 수익률: 0.9891
#
# 새로운 5분봉 생성: 2025-03-18 01:55:00
# 디버그: y_cont = 1.0360336303710938
# [진입] 상승 예측: KRW 잔고의 50%(9453 KRW)로 매수, 진입가: 2799000.00, 구매 개수: 0.0034 개
# [청산] Long 거래 - 진입가: 2799000.00, 청산가: 2800000.00, 거래 개수: 0.0034 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 81, Hit Ratio: 58.02%, 누적 수익률: 0.9890
#
# 새로운 5분봉 생성: 2025-03-18 02:00:00
# 디버그: y_cont = -0.016189996153116226
# [진입] 하락 예측: 보유 코인의 50%(0.0023 개) 매도, 진입가: 2800000.00
# [청산] Short 거래 - 진입가: 2800000.00, 청산가: 2808000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9992 (Miss)
# 거래 횟수: 82, Hit Ratio: 57.32%, 누적 수익률: 0.9883
#
# 새로운 5분봉 생성: 2025-03-18 02:05:00
# 디버그: y_cont = 0.004149983171373606
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2808000.00
# [청산] Short 거래 - 진입가: 2808000.00, 청산가: 2810000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 83, Hit Ratio: 56.63%, 누적 수익률: 0.9879
#
# 새로운 5분봉 생성: 2025-03-18 02:10:00
# 디버그: y_cont = 0.03312189504504204
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2810000.00
# [청산] Short 거래 - 진입가: 2810000.00, 청산가: 2812000.00, 거래 개수: 0.0015 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 84, Hit Ratio: 55.95%, 누적 수익률: 0.9876
#
# 새로운 5분봉 생성: 2025-03-18 02:15:00
# 디버그: y_cont = 0.9966108798980713
# [진입] 상승 예측: KRW 잔고의 50%(9893 KRW)로 매수, 진입가: 2812000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2812000.00, 청산가: 2815000.00, 거래 개수: 0.0035 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 85, Hit Ratio: 56.47%, 누적 수익률: 0.9876
#
# 새로운 5분봉 생성: 2025-03-18 02:20:00
# 디버그: y_cont = -0.031252507120370865
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2815000.00
# [청산] Short 거래 - 진입가: 2815000.00, 청산가: 2813000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 86, Hit Ratio: 56.98%, 누적 수익률: 0.9875
#
# 새로운 5분봉 생성: 2025-03-18 02:25:00
# 디버그: y_cont = -0.008691049180924892
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2813000.00
# [청산] Short 거래 - 진입가: 2813000.00, 청산가: 2813000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 87, Hit Ratio: 57.47%, 누적 수익률: 0.9873
#
# 새로운 5분봉 생성: 2025-03-18 02:30:00
# 디버그: y_cont = 1.056386947631836
# [진입] 상승 예측: KRW 잔고의 50%(9140 KRW)로 매수, 진입가: 2813000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2813000.00, 청산가: 2821000.00, 거래 개수: 0.0032 개, 거래 수익률: 1.0004 (Hit)
# 거래 횟수: 88, Hit Ratio: 57.95%, 누적 수익률: 0.9877
#
# 새로운 5분봉 생성: 2025-03-18 02:35:00
# 디버그: y_cont = -0.022110212594270706
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2821000.00
# [청산] Short 거래 - 진입가: 2821000.00, 청산가: 2820000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 89, Hit Ratio: 58.43%, 누적 수익률: 0.9876
#
# 새로운 5분봉 생성: 2025-03-18 02:40:00
# 디버그: y_cont = 1.0096626281738281
# [진입] 상승 예측: KRW 잔고의 50%(8662 KRW)로 매수, 진입가: 2820000.00, 구매 개수: 0.0031 개
# [청산] Long 거래 - 진입가: 2820000.00, 청산가: 2825000.00, 거래 개수: 0.0031 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 90, Hit Ratio: 58.89%, 누적 수익률: 0.9877
#
# 새로운 5분봉 생성: 2025-03-18 02:45:00
# 디버그: y_cont = 0.004948376677930355
# [진입] 하락 예측: 보유 코인의 50%(0.0025 개) 매도, 진입가: 2825000.00
# [청산] Short 거래 - 진입가: 2825000.00, 청산가: 2827000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 91, Hit Ratio: 58.24%, 누적 수익률: 0.9874
#
# 새로운 5분봉 생성: 2025-03-18 02:50:00
# 디버그: y_cont = -0.02088652364909649
# [진입] 하락 예측: 보유 코인의 50%(0.0020 개) 매도, 진입가: 2827000.00
# [청산] Short 거래 - 진입가: 2827000.00, 청산가: 2826000.00, 거래 개수: 0.0020 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 92, Hit Ratio: 58.70%, 누적 수익률: 0.9873
#
# 새로운 5분봉 생성: 2025-03-18 02:55:00
# 디버그: y_cont = 0.02354372665286064
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2826000.00
# [청산] Short 거래 - 진입가: 2826000.00, 청산가: 2825000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 93, Hit Ratio: 59.14%, 누적 수익률: 0.9871
#
# 새로운 5분봉 생성: 2025-03-18 03:00:00
# 디버그: y_cont = 1.0179481506347656
# [진입] 상승 예측: KRW 잔고의 50%(9501 KRW)로 매수, 진입가: 2825000.00, 구매 개수: 0.0034 개
# [청산] Long 거래 - 진입가: 2825000.00, 청산가: 2825000.00, 거래 개수: 0.0034 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 94, Hit Ratio: 58.51%, 누적 수익률: 0.9869
#
# 새로운 5분봉 생성: 2025-03-18 03:05:00
# 디버그: y_cont = 0.013495495542883873
# [진입] 하락 예측: 보유 코인의 50%(0.0023 개) 매도, 진입가: 2825000.00
# [청산] Short 거래 - 진입가: 2825000.00, 청산가: 2823000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 95, Hit Ratio: 58.95%, 누적 수익률: 0.9869
#
# 새로운 5분봉 생성: 2025-03-18 03:10:00
# 디버그: y_cont = 0.9916402697563171
# [진입] 상승 예측: KRW 잔고의 50%(8893 KRW)로 매수, 진입가: 2823000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2823000.00, 청산가: 2826000.00, 거래 개수: 0.0032 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 96, Hit Ratio: 59.38%, 누적 수익률: 0.9869
#
# 새로운 5분봉 생성: 2025-03-18 03:15:00
# 디버그: y_cont = 0.047867219895124435
# [진입] 하락 예측: 보유 코인의 50%(0.0025 개) 매도, 진입가: 2826000.00
# [청산] Short 거래 - 진입가: 2826000.00, 청산가: 2833000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9993 (Miss)
# 거래 횟수: 97, Hit Ratio: 58.76%, 누적 수익률: 0.9862
#
# 새로운 5분봉 생성: 2025-03-18 03:20:00
# 디버그: y_cont = 0.020639419555664062
# [진입] 하락 예측: 보유 코인의 50%(0.0020 개) 매도, 진입가: 2833000.00
# [청산] Short 거래 - 진입가: 2833000.00, 청산가: 2831000.00, 거래 개수: 0.0020 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 98, Hit Ratio: 59.18%, 누적 수익률: 0.9862
#
# 새로운 5분봉 생성: 2025-03-18 03:25:00
# 디버그: y_cont = 0.014469077810645103
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2831000.00
# [청산] Short 거래 - 진입가: 2831000.00, 청산가: 2834000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 99, Hit Ratio: 58.59%, 누적 수익률: 0.9857
#
# 새로운 5분봉 생성: 2025-03-18 03:30:00
# 디버그: y_cont = 0.007894405163824558
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2834000.00
# [청산] Short 거래 - 진입가: 2834000.00, 청산가: 2846000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9990 (Miss)
# 거래 횟수: 100, Hit Ratio: 58.00%, 누적 수익률: 0.9847
#
# 새로운 5분봉 생성: 2025-03-18 03:35:00
# 디버그: y_cont = 0.003527641063556075
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2846000.00
# [청산] Short 거래 - 진입가: 2846000.00, 청산가: 2843000.00, 거래 개수: 0.0016 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 101, Hit Ratio: 58.42%, 누적 수익률: 0.9847
#
# 새로운 5분봉 생성: 2025-03-18 03:40:00
# 디버그: y_cont = 1.0278838872909546
# [진입] 상승 예측: KRW 잔고의 50%(9622 KRW)로 매수, 진입가: 2843000.00, 구매 개수: 0.0034 개
# [청산] Long 거래 - 진입가: 2843000.00, 청산가: 2844000.00, 거래 개수: 0.0034 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 102, Hit Ratio: 58.82%, 누적 수익률: 0.9846
#
# 새로운 5분봉 생성: 2025-03-18 03:45:00
# 디버그: y_cont = 4.9321588448947296e-05
# [진입] 하락 예측: 보유 코인의 50%(0.0023 개) 매도, 진입가: 2844000.00
# [청산] Short 거래 - 진입가: 2844000.00, 청산가: 2843000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 103, Hit Ratio: 59.22%, 누적 수익률: 0.9845
#
# 새로운 5분봉 생성: 2025-03-18 03:50:00
# 디버그: y_cont = 0.027623511850833893
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2843000.00
# [청산] Short 거래 - 진입가: 2843000.00, 청산가: 2842000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 104, Hit Ratio: 59.62%, 누적 수익률: 0.9843
#
# 새로운 5분봉 생성: 2025-03-18 03:55:00
# 디버그: y_cont = 0.012992409989237785
# [진입] 하락 예측: 보유 코인의 50%(0.0014 개) 매도, 진입가: 2842000.00
# [청산] Short 거래 - 진입가: 2842000.00, 청산가: 2842000.00, 거래 개수: 0.0014 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 105, Hit Ratio: 60.00%, 누적 수익률: 0.9842
#
# 새로운 5분봉 생성: 2025-03-18 04:00:00
# 디버그: y_cont = -0.00275750202126801
# [진입] 하락 예측: 보유 코인의 50%(0.0014 개) 매도, 진입가: 2842000.00
# [청산] Short 거래 - 진입가: 2842000.00, 청산가: 2847000.00, 거래 개수: 0.0014 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 106, Hit Ratio: 59.43%, 누적 수익률: 0.9836
#
# 새로운 5분봉 생성: 2025-03-18 04:05:00
# 디버그: y_cont = 0.0055402484722435474
# [진입] 하락 예측: 보유 코인의 50%(0.0014 개) 매도, 진입가: 2847000.00
# [청산] Short 거래 - 진입가: 2847000.00, 청산가: 2845000.00, 거래 개수: 0.0014 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 107, Hit Ratio: 59.81%, 누적 수익률: 0.9835
#
# 새로운 5분봉 생성: 2025-03-18 04:10:00
# 디버그: y_cont = 0.6113635301589966
# [진입] 상승 예측: KRW 잔고의 50%(10001 KRW)로 매수, 진입가: 2845000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2845000.00, 청산가: 2844000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 108, Hit Ratio: 59.26%, 누적 수익률: 0.9833
#
# 새로운 5분봉 생성: 2025-03-18 04:15:00
# 디버그: y_cont = 0.0058332281187176704
# [진입] 하락 예측: 보유 코인의 50%(0.0021 개) 매도, 진입가: 2844000.00
# [청산] Short 거래 - 진입가: 2844000.00, 청산가: 2840000.00, 거래 개수: 0.0021 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 109, Hit Ratio: 59.63%, 누적 수익률: 0.9834
#
# 새로운 5분봉 생성: 2025-03-18 04:20:00
# 디버그: y_cont = 0.04624348506331444
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2840000.00
# [청산] Short 거래 - 진입가: 2840000.00, 청산가: 2842000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 110, Hit Ratio: 59.09%, 누적 수익률: 0.9830
#
# 새로운 5분봉 생성: 2025-03-18 04:25:00
# 디버그: y_cont = 0.005745653994381428
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2842000.00
# [청산] Short 거래 - 진입가: 2842000.00, 청산가: 2838000.00, 거래 개수: 0.0017 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 111, Hit Ratio: 59.46%, 누적 수익률: 0.9831
#
# 새로운 5분봉 생성: 2025-03-18 04:30:00
# 디버그: y_cont = 0.00991866085678339
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2838000.00
# [청산] Short 거래 - 진입가: 2838000.00, 청산가: 2839000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 112, Hit Ratio: 58.93%, 누적 수익률: 0.9828
#
# 새로운 5분봉 생성: 2025-03-18 04:35:00
# 디버그: y_cont = -0.028020942583680153
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2839000.00
# [청산] Short 거래 - 진입가: 2839000.00, 청산가: 2839000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 113, Hit Ratio: 59.29%, 누적 수익률: 0.9826
#
# 새로운 5분봉 생성: 2025-03-18 04:40:00
# 디버그: y_cont = 0.8991551995277405
# [진입] 상승 예측: KRW 잔고의 50%(9219 KRW)로 매수, 진입가: 2839000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2839000.00, 청산가: 2840000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 114, Hit Ratio: 59.65%, 누적 수익률: 0.9825
#
# 새로운 5분봉 생성: 2025-03-18 04:45:00
# 디버그: y_cont = 1.0550646781921387
# [진입] 상승 예측: KRW 잔고의 50%(7374 KRW)로 매수, 진입가: 2840000.00, 구매 개수: 0.0026 개
# [청산] Long 거래 - 진입가: 2840000.00, 청산가: 2840000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 115, Hit Ratio: 59.13%, 누적 수익률: 0.9823
#
# 새로운 5분봉 생성: 2025-03-18 04:50:00
# 디버그: y_cont = 0.0042377058416605
# [진입] 하락 예측: 보유 코인의 50%(0.0029 개) 매도, 진입가: 2840000.00
# [청산] Short 거래 - 진입가: 2840000.00, 청산가: 2834000.00, 거래 개수: 0.0029 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 116, Hit Ratio: 59.48%, 누적 수익률: 0.9825
#
# 새로운 5분봉 생성: 2025-03-18 04:55:00
# 디버그: y_cont = -0.0005307202227413654
# [진입] 하락 예측: 보유 코인의 50%(0.0023 개) 매도, 진입가: 2834000.00
# [청산] Short 거래 - 진입가: 2834000.00, 청산가: 2835000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 117, Hit Ratio: 58.97%, 누적 수익률: 0.9823
#
# 새로운 5분봉 생성: 2025-03-18 05:00:00
# 디버그: y_cont = 0.016648096963763237
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2835000.00
# [청산] Short 거래 - 진입가: 2835000.00, 청산가: 2828000.00, 거래 개수: 0.0018 개, 거래 수익률: 1.0003 (Hit)
# 거래 횟수: 118, Hit Ratio: 59.32%, 누적 수익률: 0.9826
#
# 새로운 5분봉 생성: 2025-03-18 05:05:00
# 디버그: y_cont = 0.8932585716247559
# [진입] 상승 예측: KRW 잔고의 50%(9888 KRW)로 매수, 진입가: 2828000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2828000.00, 청산가: 2827000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 119, Hit Ratio: 58.82%, 누적 수익률: 0.9823
#
# 새로운 5분봉 생성: 2025-03-18 05:10:00
# 디버그: y_cont = 1.038655161857605
# [진입] 상승 예측: KRW 잔고의 50%(7909 KRW)로 매수, 진입가: 2828000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2828000.00, 청산가: 2826000.00, 거래 개수: 0.0028 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 120, Hit Ratio: 58.33%, 누적 수익률: 0.9820
#
# 새로운 5분봉 생성: 2025-03-18 05:15:00
# 디버그: y_cont = 1.002495288848877
# [진입] 상승 예측: KRW 잔고의 50%(6327 KRW)로 매수, 진입가: 2826000.00, 구매 개수: 0.0022 개
# [청산] Long 거래 - 진입가: 2826000.00, 청산가: 2829000.00, 거래 개수: 0.0022 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 121, Hit Ratio: 58.68%, 누적 수익률: 0.9820
#
# 새로운 5분봉 생성: 2025-03-18 05:20:00
# 디버그: y_cont = 1.0123770236968994
# [진입] 상승 예측: KRW 잔고의 50%(5061 KRW)로 매수, 진입가: 2827000.00, 구매 개수: 0.0018 개
# [청산] Long 거래 - 진입가: 2827000.00, 청산가: 2827000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 122, Hit Ratio: 58.20%, 누적 수익률: 0.9818
#
# 새로운 5분봉 생성: 2025-03-18 05:25:00
# 디버그: y_cont = 0.03977331519126892
# [진입] 하락 예측: 보유 코인의 50%(0.0035 개) 매도, 진입가: 2827000.00
# [청산] Short 거래 - 진입가: 2827000.00, 청산가: 2822000.00, 거래 개수: 0.0035 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 123, Hit Ratio: 58.54%, 누적 수익률: 0.9819
#
# 새로운 5분봉 생성: 2025-03-18 05:30:00
# 디버그: y_cont = 0.9872825741767883
# [진입] 상승 예측: KRW 잔고의 50%(6048 KRW)로 매수, 진입가: 2822000.00, 구매 개수: 0.0021 개
# [청산] Long 거래 - 진입가: 2822000.00, 청산가: 2824000.00, 거래 개수: 0.0021 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 124, Hit Ratio: 58.87%, 누적 수익률: 0.9819
#
# 새로운 5분봉 생성: 2025-03-18 05:35:00
# 디버그: y_cont = 1.027642846107483
# [진입] 상승 예측: KRW 잔고의 50%(4838 KRW)로 매수, 진입가: 2824000.00, 구매 개수: 0.0017 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2824000.00, 청산가: 2820000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 125, Hit Ratio: 58.40%, 누적 수익률: 0.9814
#
# 새로운 5분봉 생성: 2025-03-18 05:40:00
# 디버그: y_cont = 1.0013575553894043
# [진입] 상승 예측: KRW 잔고의 50%(4838 KRW)로 매수, 진입가: 2820000.00, 구매 개수: 0.0017 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2820000.00, 청산가: 2829000.00, 거래 개수: 0.0017 개, 거래 수익률: 1.0004 (Hit)
# 거래 횟수: 126, Hit Ratio: 58.73%, 누적 수익률: 0.9818
#
# 새로운 5분봉 생성: 2025-03-18 05:45:00
# 디버그: y_cont = 0.020624449476599693
# [진입] 하락 예측: 보유 코인의 50%(0.0033 개) 매도, 진입가: 2829000.00
# [청산] Short 거래 - 진입가: 2829000.00, 청산가: 2832000.00, 거래 개수: 0.0033 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 127, Hit Ratio: 58.27%, 누적 수익률: 0.9814
#
# 새로운 5분봉 생성: 2025-03-18 05:50:00
# 디버그: y_cont = 0.9934515357017517
# [진입] 상승 예측: KRW 잔고의 50%(6682 KRW)로 매수, 진입가: 2832000.00, 구매 개수: 0.0024 개
# [청산] Long 거래 - 진입가: 2832000.00, 청산가: 2828000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 128, Hit Ratio: 57.81%, 누적 수익률: 0.9810
#
# 새로운 5분봉 생성: 2025-03-18 05:55:00
# 디버그: y_cont = 1.0253572463989258
# [진입] 상승 예측: KRW 잔고의 50%(5345 KRW)로 매수, 진입가: 2828000.00, 구매 개수: 0.0019 개
# [청산] Long 거래 - 진입가: 2828000.00, 청산가: 2825000.00, 거래 개수: 0.0019 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 129, Hit Ratio: 57.36%, 누적 수익률: 0.9805
#
# 새로운 5분봉 생성: 2025-03-18 06:00:00
# 디버그: y_cont = 0.023112351074814796
# [진입] 하락 예측: 보유 코인의 50%(0.0035 개) 매도, 진입가: 2825000.00
# [청산] Short 거래 - 진입가: 2825000.00, 청산가: 2828000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 130, Hit Ratio: 56.92%, 누적 수익률: 0.9801
#
# 새로운 5분봉 생성: 2025-03-18 06:05:00
# 디버그: y_cont = 0.005245275795459747
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2828000.00
# [청산] Short 거래 - 진입가: 2828000.00, 청산가: 2825000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 131, Hit Ratio: 57.25%, 누적 수익률: 0.9802
#
# 새로운 5분봉 생성: 2025-03-18 06:10:00
# 디버그: y_cont = 0.9410486817359924
# [진입] 상승 예측: KRW 잔고의 50%(7791 KRW)로 매수, 진입가: 2825000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2825000.00, 청산가: 2828000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 132, Hit Ratio: 57.58%, 누적 수익률: 0.9802
#
# 새로운 5분봉 생성: 2025-03-18 06:15:00
# 디버그: y_cont = 1.0009353160858154
# [진입] 상승 예측: KRW 잔고의 50%(6232 KRW)로 매수, 진입가: 2828000.00, 구매 개수: 0.0022 개
# [청산] Long 거래 - 진입가: 2828000.00, 청산가: 2832000.00, 거래 개수: 0.0022 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 133, Hit Ratio: 57.89%, 누적 수익률: 0.9803
#
# 새로운 5분봉 생성: 2025-03-18 06:20:00
# 디버그: y_cont = -0.036973584443330765
# [진입] 하락 예측: 보유 코인의 50%(0.0032 개) 매도, 진입가: 2832000.00
# [청산] Short 거래 - 진입가: 2832000.00, 청산가: 2833000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 134, Hit Ratio: 57.46%, 누적 수익률: 0.9800
#
# 새로운 5분봉 생성: 2025-03-18 06:25:00
# 디버그: y_cont = -0.010189562104642391
# [진입] 하락 예측: 보유 코인의 50%(0.0026 개) 매도, 진입가: 2833000.00
# [청산] Short 거래 - 진입가: 2833000.00, 청산가: 2833000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 135, Hit Ratio: 57.78%, 누적 수익률: 0.9798
#
# 새로운 5분봉 생성: 2025-03-18 06:30:00
# 디버그: y_cont = 0.9578829407691956
# [진입] 상승 예측: KRW 잔고의 50%(8250 KRW)로 매수, 진입가: 2833000.00, 구매 개수: 0.0029 개
# [청산] Long 거래 - 진입가: 2833000.00, 청산가: 2836000.00, 거래 개수: 0.0029 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 136, Hit Ratio: 58.09%, 누적 수익률: 0.9798
#
# 새로운 5분봉 생성: 2025-03-18 06:35:00
# 디버그: y_cont = 0.8862397074699402
# [진입] 상승 예측: KRW 잔고의 50%(6599 KRW)로 매수, 진입가: 2836000.00, 구매 개수: 0.0023 개
# [청산] Long 거래 - 진입가: 2836000.00, 청산가: 2837000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 137, Hit Ratio: 58.39%, 누적 수익률: 0.9797
#
# 새로운 5분봉 생성: 2025-03-18 06:40:00
# 디버그: y_cont = 0.9562881588935852
# [진입] 상승 예측: KRW 잔고의 50%(5279 KRW)로 매수, 진입가: 2837000.00, 구매 개수: 0.0019 개
# [청산] Long 거래 - 진입가: 2837000.00, 청산가: 2834000.00, 거래 개수: 0.0019 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 138, Hit Ratio: 57.97%, 누적 수익률: 0.9793
#
# 새로운 5분봉 생성: 2025-03-18 06:45:00
# 디버그: y_cont = 0.003473410615697503
# [진입] 하락 예측: 보유 코인의 50%(0.0035 개) 매도, 진입가: 2836000.00
# [청산] Short 거래 - 진입가: 2836000.00, 청산가: 2839000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 139, Hit Ratio: 57.55%, 누적 수익률: 0.9789
#
# 새로운 5분봉 생성: 2025-03-18 06:50:00
# 디버그: y_cont = 0.02591114304959774
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2839000.00
# [청산] Short 거래 - 진입가: 2839000.00, 청산가: 2839000.00, 거래 개수: 0.0028 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 140, Hit Ratio: 57.86%, 누적 수익률: 0.9787
#
# 새로운 5분봉 생성: 2025-03-18 06:55:00
# 디버그: y_cont = 0.0068381065502762794
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2839000.00
# [청산] Short 거래 - 진입가: 2839000.00, 청산가: 2838000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 141, Hit Ratio: 58.16%, 누적 수익률: 0.9785
#
# 새로운 5분봉 생성: 2025-03-18 07:00:00
# 디버그: y_cont = -0.010727069340646267
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2838000.00
# [청산] Short 거래 - 진입가: 2838000.00, 청산가: 2836000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 142, Hit Ratio: 58.45%, 누적 수익률: 0.9785
#
# 새로운 5분봉 생성: 2025-03-18 07:05:00
# 디버그: y_cont = 0.9658746719360352
# [진입] 상승 예측: KRW 잔고의 50%(10033 KRW)로 매수, 진입가: 2836000.00, 구매 개수: 0.0035 개
# [청산] Long 거래 - 진입가: 2836000.00, 청산가: 2837000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 143, Hit Ratio: 58.74%, 누적 수익률: 0.9784
#
# 새로운 5분봉 생성: 2025-03-18 07:10:00
# 디버그: y_cont = 0.018953466787934303
# [진입] 하락 예측: 보유 코인의 50%(0.0021 개) 매도, 진입가: 2837000.00
# [청산] Short 거래 - 진입가: 2837000.00, 청산가: 2838000.00, 거래 개수: 0.0021 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 144, Hit Ratio: 58.33%, 누적 수익률: 0.9781
#
# 새로운 5분봉 생성: 2025-03-18 07:15:00
# 디버그: y_cont = -0.019769661128520966
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2838000.00
# [청산] Short 거래 - 진입가: 2838000.00, 청산가: 2838000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 145, Hit Ratio: 58.62%, 누적 수익률: 0.9779
#
# 새로운 5분봉 생성: 2025-03-18 07:20:00
# 디버그: y_cont = 0.02431798353791237
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2838000.00
# [청산] Short 거래 - 진입가: 2838000.00, 청산가: 2832000.00, 거래 개수: 0.0017 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 146, Hit Ratio: 58.90%, 누적 수익률: 0.9781
#
# 새로운 5분봉 생성: 2025-03-18 07:25:00
# 디버그: y_cont = -0.0022706538438796997
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2832000.00
# [청산] Short 거래 - 진입가: 2832000.00, 청산가: 2832000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 147, Hit Ratio: 59.18%, 누적 수익률: 0.9779
#
# 새로운 5분봉 생성: 2025-03-18 07:30:00
# 디버그: y_cont = 0.03632814437150955
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2832000.00
# [청산] Short 거래 - 진입가: 2832000.00, 청산가: 2837000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 148, Hit Ratio: 58.78%, 누적 수익률: 0.9774
#
# 새로운 5분봉 생성: 2025-03-18 07:35:00
# 디버그: y_cont = 1.0360735654830933
# [진입] 상승 예측: KRW 잔고의 50%(9232 KRW)로 매수, 진입가: 2837000.00, 구매 개수: 0.0033 개
# [청산] Long 거래 - 진입가: 2837000.00, 청산가: 2835000.00, 거래 개수: 0.0033 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 149, Hit Ratio: 58.39%, 누적 수익률: 0.9771
#
# 새로운 5분봉 생성: 2025-03-18 07:40:00
# 디버그: y_cont = 1.0098527669906616
# [진입] 상승 예측: KRW 잔고의 50%(7385 KRW)로 매수, 진입가: 2833000.00, 구매 개수: 0.0026 개
# [청산] Long 거래 - 진입가: 2833000.00, 청산가: 2831000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 150, Hit Ratio: 58.00%, 누적 수익률: 0.9767
#
# 새로운 5분봉 생성: 2025-03-18 07:45:00
# 디버그: y_cont = 0.041425567120313644
# [진입] 하락 예측: 보유 코인의 50%(0.0029 개) 매도, 진입가: 2830000.00
# [청산] Short 거래 - 진입가: 2830000.00, 청산가: 2830000.00, 거래 개수: 0.0029 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 151, Hit Ratio: 58.28%, 누적 수익률: 0.9765
#
# 새로운 5분봉 생성: 2025-03-18 07:50:00
# 디버그: y_cont = 0.04064036160707474
# [진입] 하락 예측: 보유 코인의 50%(0.0023 개) 매도, 진입가: 2830000.00
# [청산] Short 거래 - 진입가: 2830000.00, 청산가: 2830000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 152, Hit Ratio: 58.55%, 누적 수익률: 0.9763
#
# 새로운 5분봉 생성: 2025-03-18 07:55:00
# 디버그: y_cont = 1.0071780681610107
# [진입] 상승 예측: KRW 잔고의 50%(8834 KRW)로 매수, 진입가: 2830000.00, 구매 개수: 0.0031 개
# [청산] Long 거래 - 진입가: 2830000.00, 청산가: 2828000.00, 거래 개수: 0.0031 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 153, Hit Ratio: 58.17%, 누적 수익률: 0.9760
#
# 새로운 5분봉 생성: 2025-03-18 08:00:00
# 디버그: y_cont = 0.9901436567306519
# [진입] 상승 예측: KRW 잔고의 50%(7067 KRW)로 매수, 진입가: 2828000.00, 구매 개수: 0.0025 개
# [청산] Long 거래 - 진입가: 2828000.00, 청산가: 2825000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 154, Hit Ratio: 57.79%, 누적 수익률: 0.9756
#
# 새로운 5분봉 생성: 2025-03-18 08:05:00
# 디버그: y_cont = 0.9397146701812744
# [진입] 상승 예측: KRW 잔고의 50%(5653 KRW)로 매수, 진입가: 2826000.00, 구매 개수: 0.0020 개
# [청산] Long 거래 - 진입가: 2826000.00, 청산가: 2826000.00, 거래 개수: 0.0020 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 155, Hit Ratio: 57.42%, 누적 수익률: 0.9754
#
# 새로운 5분봉 생성: 2025-03-18 08:10:00
# 디버그: y_cont = 0.020556192845106125
# [진입] 하락 예측: 보유 코인의 50%(0.0034 개) 매도, 진입가: 2826000.00
# [청산] Short 거래 - 진입가: 2826000.00, 청산가: 2820000.00, 거래 개수: 0.0034 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 156, Hit Ratio: 57.69%, 누적 수익률: 0.9756
#
# 새로운 5분봉 생성: 2025-03-18 08:15:00
# 디버그: y_cont = 0.020962489768862724
# [진입] 하락 예측: 보유 코인의 50%(0.0027 개) 매도, 진입가: 2820000.00
# [청산] Short 거래 - 진입가: 2820000.00, 청산가: 2824000.00, 거래 개수: 0.0027 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 157, Hit Ratio: 57.32%, 누적 수익률: 0.9751
#
# 새로운 5분봉 생성: 2025-03-18 08:20:00
# 디버그: y_cont = 1.0197092294692993
# [진입] 상승 예측: KRW 잔고의 50%(7938 KRW)로 매수, 진입가: 2824000.00, 구매 개수: 0.0028 개
# [청산] Long 거래 - 진입가: 2824000.00, 청산가: 2817000.00, 거래 개수: 0.0028 개, 거래 수익률: 0.9993 (Miss)
# 거래 횟수: 158, Hit Ratio: 56.96%, 누적 수익률: 0.9745
#
# 새로운 5분봉 생성: 2025-03-18 08:25:00
# 디버그: y_cont = 0.006399893201887608
# [진입] 하락 예측: 보유 코인의 50%(0.0027 개) 매도, 진입가: 2817000.00
# [청산] Short 거래 - 진입가: 2817000.00, 청산가: 2814000.00, 거래 개수: 0.0027 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 159, Hit Ratio: 57.23%, 누적 수익률: 0.9745
#
# 새로운 5분봉 생성: 2025-03-18 08:30:00
# 디버그: y_cont = -0.011420650407671928
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2814000.00
# [청산] Short 거래 - 진입가: 2814000.00, 청산가: 2818000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 160, Hit Ratio: 56.88%, 누적 수익률: 0.9740
#
# 새로운 5분봉 생성: 2025-03-18 08:35:00
# 디버그: y_cont = 0.018302425742149353
# [진입] 하락 예측: 보유 코인의 50%(0.0017 개) 매도, 진입가: 2818000.00
# [청산] Short 거래 - 진입가: 2818000.00, 청산가: 2819000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 161, Hit Ratio: 56.52%, 누적 수익률: 0.9737
#
# 새로운 5분봉 생성: 2025-03-18 08:40:00
# 디버그: y_cont = 0.97822505235672
# [진입] 상승 예측: KRW 잔고의 50%(9100 KRW)로 매수, 진입가: 2819000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2819000.00, 청산가: 2823000.00, 거래 개수: 0.0032 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 162, Hit Ratio: 56.79%, 누적 수익률: 0.9738
#
# 새로운 5분봉 생성: 2025-03-18 08:45:00
# 디버그: y_cont = 0.9761024713516235
# [진입] 상승 예측: KRW 잔고의 50%(7279 KRW)로 매수, 진입가: 2823000.00, 구매 개수: 0.0026 개
# [청산] Long 거래 - 진입가: 2823000.00, 청산가: 2824000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 163, Hit Ratio: 57.06%, 누적 수익률: 0.9737
#
# 새로운 5분봉 생성: 2025-03-18 08:50:00
# 디버그: y_cont = 0.03327260538935661
# [진입] 하락 예측: 보유 코인의 50%(0.0029 개) 매도, 진입가: 2821000.00
# [청산] Short 거래 - 진입가: 2821000.00, 청산가: 2817000.00, 거래 개수: 0.0029 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 164, Hit Ratio: 57.32%, 누적 수익률: 0.9738
#
# 새로운 5분봉 생성: 2025-03-18 08:55:00
# 디버그: y_cont = 0.9392273426055908
# [진입] 상승 예측: KRW 잔고의 50%(7458 KRW)로 매수, 진입가: 2817000.00, 구매 개수: 0.0026 개
# [청산] Long 거래 - 진입가: 2817000.00, 청산가: 2818000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 165, Hit Ratio: 57.58%, 누적 수익률: 0.9737
#
# 새로운 5분봉 생성: 2025-03-18 09:00:00
# 디버그: y_cont = 1.022969126701355
# [진입] 상승 예측: KRW 잔고의 50%(5965 KRW)로 매수, 진입가: 2819000.00, 구매 개수: 0.0021 개
# [청산] Long 거래 - 진입가: 2819000.00, 청산가: 2816000.00, 거래 개수: 0.0021 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 166, Hit Ratio: 57.23%, 누적 수익률: 0.9733
#
# 새로운 5분봉 생성: 2025-03-18 09:05:00
# 디버그: y_cont = 0.02506433241069317
# [진입] 하락 예측: 보유 코인의 50%(0.0033 개) 매도, 진입가: 2816000.00
# [청산] Short 거래 - 진입가: 2816000.00, 청산가: 2817000.00, 거래 개수: 0.0033 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 167, Hit Ratio: 56.89%, 누적 수익률: 0.9730
#
# 새로운 5분봉 생성: 2025-03-18 09:10:00
# 디버그: y_cont = 1.0770784616470337
# [진입] 상승 예측: KRW 잔고의 50%(6612 KRW)로 매수, 진입가: 2817000.00, 구매 개수: 0.0023 개
# [청산] Long 거래 - 진입가: 2817000.00, 청산가: 2815000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 168, Hit Ratio: 56.55%, 누적 수익률: 0.9727
#
# 새로운 5분봉 생성: 2025-03-18 09:15:00
# 디버그: y_cont = 1.0526630878448486
# [진입] 상승 예측: KRW 잔고의 50%(5289 KRW)로 매수, 진입가: 2815000.00, 구매 개수: 0.0019 개
# [청산] Long 거래 - 진입가: 2815000.00, 청산가: 2819000.00, 거래 개수: 0.0019 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 169, Hit Ratio: 56.80%, 누적 수익률: 0.9727
#
# 새로운 5분봉 생성: 2025-03-18 09:20:00
# 디버그: y_cont = 0.9781202673912048
# [진입] 상승 예측: KRW 잔고의 50%(4231 KRW)로 매수, 진입가: 2819000.00, 구매 개수: 0.0015 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2819000.00, 청산가: 2816000.00, 거래 개수: 0.0015 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 170, Hit Ratio: 56.47%, 누적 수익률: 0.9723
#
# 새로운 5분봉 생성: 2025-03-18 09:25:00
# 디버그: y_cont = 0.009669043123722076
# [진입] 하락 예측: 보유 코인의 50%(0.0035 개) 매도, 진입가: 2816000.00
# [청산] Short 거래 - 진입가: 2816000.00, 청산가: 2812000.00, 거래 개수: 0.0035 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 171, Hit Ratio: 56.73%, 누적 수익률: 0.9724
#
# 새로운 5분봉 생성: 2025-03-18 09:30:00
# 디버그: y_cont = 0.02438296191394329
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2812000.00
# [청산] Short 거래 - 진입가: 2812000.00, 청산가: 2816000.00, 거래 개수: 0.0028 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 172, Hit Ratio: 56.40%, 누적 수익률: 0.9720
#
# 새로운 5분봉 생성: 2025-03-18 09:35:00
# 디버그: y_cont = 0.969176709651947
# [진입] 상승 예측: KRW 잔고의 50%(7736 KRW)로 매수, 진입가: 2817000.00, 구매 개수: 0.0027 개
# [청산] Long 거래 - 진입가: 2817000.00, 청산가: 2818000.00, 거래 개수: 0.0027 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 173, Hit Ratio: 56.65%, 누적 수익률: 0.9718
#
# 새로운 5분봉 생성: 2025-03-18 09:40:00
# 디버그: y_cont = 0.014021119102835655
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2818000.00
# [청산] Short 거래 - 진입가: 2818000.00, 청산가: 2814000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 174, Hit Ratio: 56.90%, 누적 수익률: 0.9719
#
# 새로운 5분봉 생성: 2025-03-18 09:45:00
# 디버그: y_cont = 0.0424969457089901
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2814000.00
# [청산] Short 거래 - 진입가: 2814000.00, 청산가: 2812000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 175, Hit Ratio: 57.14%, 누적 수익률: 0.9719
#
# 새로운 5분봉 생성: 2025-03-18 09:50:00
# 디버그: y_cont = 0.9621164202690125
# [진입] 상승 예측: KRW 잔고의 50%(8989 KRW)로 매수, 진입가: 2812000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2812000.00, 청산가: 2807000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 176, Hit Ratio: 56.82%, 누적 수익률: 0.9713
#
# 새로운 5분봉 생성: 2025-03-18 09:55:00
# 디버그: y_cont = 0.00865206215530634
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2807000.00
# [청산] Short 거래 - 진입가: 2807000.00, 청산가: 2808000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 177, Hit Ratio: 56.50%, 누적 수익률: 0.9711
#
# 새로운 5분봉 생성: 2025-03-18 10:00:00
# 디버그: y_cont = 1.0270700454711914
# [진입] 상승 예측: KRW 잔고의 50%(8542 KRW)로 매수, 진입가: 2808000.00, 구매 개수: 0.0030 개
# [청산] Long 거래 - 진입가: 2808000.00, 청산가: 2813000.00, 거래 개수: 0.0030 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 178, Hit Ratio: 56.74%, 누적 수익률: 0.9712
#
# 새로운 5분봉 생성: 2025-03-18 10:05:00
# 디버그: y_cont = 1.0369545221328735
# [진입] 상승 예측: KRW 잔고의 50%(6832 KRW)로 매수, 진입가: 2813000.00, 구매 개수: 0.0024 개
# [청산] Long 거래 - 진입가: 2813000.00, 청산가: 2805000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9992 (Miss)
# 거래 횟수: 179, Hit Ratio: 56.42%, 누적 수익률: 0.9705
#
# 새로운 5분봉 생성: 2025-03-18 10:10:00
# 디버그: y_cont = 1.0031371116638184
# [진입] 상승 예측: KRW 잔고의 50%(5465 KRW)로 매수, 진입가: 2805000.00, 구매 개수: 0.0019 개
# [청산] Long 거래 - 진입가: 2805000.00, 청산가: 2803000.00, 거래 개수: 0.0019 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 180, Hit Ratio: 56.11%, 누적 수익률: 0.9701
#
# 새로운 5분봉 생성: 2025-03-18 10:15:00
# 디버그: y_cont = 1.0034022331237793
# [진입] 상승 예측: KRW 잔고의 50%(4372 KRW)로 매수, 진입가: 2803000.00, 구매 개수: 0.0016 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2803000.00, 청산가: 2799000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 181, Hit Ratio: 55.80%, 누적 수익률: 0.9697
#
# 새로운 5분봉 생성: 2025-03-18 10:20:00
# 디버그: y_cont = 0.9904540777206421
# [진입] 상승 예측: KRW 잔고의 50%(4372 KRW)로 매수, 진입가: 2799000.00, 구매 개수: 0.0016 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2799000.00, 청산가: 2795000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 182, Hit Ratio: 55.49%, 누적 수익률: 0.9692
#
# 새로운 5분봉 생성: 2025-03-18 10:25:00
# 디버그: y_cont = 0.9689223170280457
# [진입] 상승 예측: KRW 잔고의 50%(4372 KRW)로 매수, 진입가: 2796000.00, 구매 개수: 0.0016 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2796000.00, 청산가: 2801000.00, 거래 개수: 0.0016 개, 거래 수익률: 1.0002 (Hit)
# ...
#
# 새로운 5분봉 생성: 2025-03-18 19:20:00
# 디버그: y_cont = 0.008122899569571018
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2771000.00
# [청산] Short 거래 - 진입가: 2771000.00, 청산가: 2773000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 290, Hit Ratio: 51.38%, 누적 수익률: 0.9473
#
# 새로운 5분봉 생성: 2025-03-18 19:25:00
# 디버그: y_cont = 0.9927681088447571
# [진입] 상승 예측: KRW 잔고의 50%(8871 KRW)로 매수, 진입가: 2774000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2774000.00, 청산가: 2776000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 291, Hit Ratio: 51.55%, 누적 수익률: 0.9473
#
# 새로운 5분봉 생성: 2025-03-18 19:30:00
# 디버그: y_cont = 1.0351746082305908
# [진입] 상승 예측: KRW 잔고의 50%(7096 KRW)로 매수, 진입가: 2775000.00, 구매 개수: 0.0026 개
# [청산] Long 거래 - 진입가: 2775000.00, 청산가: 2773000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 292, Hit Ratio: 51.37%, 누적 수익률: 0.9470
#
# 새로운 5분봉 생성: 2025-03-18 19:35:00
# 디버그: y_cont = 0.9834199547767639
# [진입] 상승 예측: KRW 잔고의 50%(5676 KRW)로 매수, 진입가: 2771000.00, 구매 개수: 0.0020 개
# [청산] Long 거래 - 진입가: 2771000.00, 청산가: 2782000.00, 거래 개수: 0.0020 개, 거래 수익률: 1.0006 (Hit)
# 거래 횟수: 293, Hit Ratio: 51.54%, 누적 수익률: 0.9475
#
# 새로운 5분봉 생성: 2025-03-18 19:40:00
# 디버그: y_cont = 0.00018339311645831913
# [진입] 하락 예측: 보유 코인의 50%(0.0033 개) 매도, 진입가: 2781000.00
# [청산] Short 거래 - 진입가: 2781000.00, 청산가: 2784000.00, 거래 개수: 0.0033 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 294, Hit Ratio: 51.36%, 누적 수익률: 0.9471
#
# 새로운 5분봉 생성: 2025-03-18 19:45:00
# 디버그: y_cont = 1.001298189163208
# [진입] 상승 예측: KRW 잔고의 50%(6390 KRW)로 매수, 진입가: 2783000.00, 구매 개수: 0.0023 개
# [청산] Long 거래 - 진입가: 2783000.00, 청산가: 2783000.00, 거래 개수: 0.0023 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 295, Hit Ratio: 51.19%, 누적 수익률: 0.9469
#
# 새로운 5분봉 생성: 2025-03-18 19:50:00
# 디버그: y_cont = -0.0008292873972095549
# [진입] 하락 예측: 보유 코인의 50%(0.0031 개) 매도, 진입가: 2783000.00
# [청산] Short 거래 - 진입가: 2783000.00, 청산가: 2782000.00, 거래 개수: 0.0031 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 296, Hit Ratio: 51.35%, 누적 수익률: 0.9468
#
# 새로운 5분봉 생성: 2025-03-18 19:55:00
# 디버그: y_cont = 0.9570114016532898
# [진입] 상승 예측: KRW 잔고의 50%(6845 KRW)로 매수, 진입가: 2782000.00, 구매 개수: 0.0025 개
# [청산] Long 거래 - 진입가: 2782000.00, 청산가: 2782000.00, 거래 개수: 0.0025 개, 거래 수익률: 0.9998 (Miss)
# 거래 횟수: 297, Hit Ratio: 51.18%, 누적 수익률: 0.9466
#
# 새로운 5분봉 생성: 2025-03-18 20:00:00
# 디버그: y_cont = 0.9874176979064941
# [진입] 상승 예측: KRW 잔고의 50%(5476 KRW)로 매수, 진입가: 2783000.00, 구매 개수: 0.0020 개
# [청산] Long 거래 - 진입가: 2783000.00, 청산가: 2779000.00, 거래 개수: 0.0020 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 298, Hit Ratio: 51.01%, 누적 수익률: 0.9462
#
# 새로운 5분봉 생성: 2025-03-18 20:05:00
# 디버그: y_cont = -0.022606156766414642
# [진입] 하락 예측: 보유 코인의 50%(0.0034 개) 매도, 진입가: 2779000.00
# [청산] Short 거래 - 진입가: 2779000.00, 청산가: 2778000.00, 거래 개수: 0.0034 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 299, Hit Ratio: 51.17%, 누적 수익률: 0.9460
#
# 새로운 5분봉 생성: 2025-03-18 20:10:00
# 디버그: y_cont = 0.9775673151016235
# [진입] 상승 예측: KRW 잔고의 50%(6259 KRW)로 매수, 진입가: 2778000.00, 구매 개수: 0.0023 개
# [청산] Long 거래 - 진입가: 2778000.00, 청산가: 2785000.00, 거래 개수: 0.0023 개, 거래 수익률: 1.0003 (Hit)
# 거래 횟수: 300, Hit Ratio: 51.33%, 누적 수익률: 0.9463
#
# 새로운 5분봉 생성: 2025-03-18 20:15:00
# 디버그: y_cont = 0.9733111262321472
# [진입] 상승 예측: KRW 잔고의 50%(5006 KRW)로 매수, 진입가: 2785000.00, 구매 개수: 0.0018 개
# [청산] Long 거래 - 진입가: 2785000.00, 청산가: 2781000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 301, Hit Ratio: 51.16%, 누적 수익률: 0.9459
#
# 새로운 5분봉 생성: 2025-03-18 20:20:00
# 디버그: y_cont = 0.006120520643889904
# [진입] 하락 예측: 보유 코인의 50%(0.0035 개) 매도, 진입가: 2781000.00
# [청산] Short 거래 - 진입가: 2781000.00, 청산가: 2783000.00, 거래 개수: 0.0035 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 302, Hit Ratio: 50.99%, 누적 수익률: 0.9455
#
# 새로운 5분봉 생성: 2025-03-18 20:25:00
# 디버그: y_cont = 1.0064818859100342
# [진입] 상승 예측: KRW 잔고의 50%(5959 KRW)로 매수, 진입가: 2783000.00, 구매 개수: 0.0021 개
# [청산] Long 거래 - 진입가: 2783000.00, 청산가: 2779000.00, 거래 개수: 0.0021 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 303, Hit Ratio: 50.83%, 누적 수익률: 0.9451
#
# 새로운 5분봉 생성: 2025-03-18 20:30:00
# 디버그: y_cont = 0.9721088409423828
# [진입] 상승 예측: KRW 잔고의 50%(4766 KRW)로 매수, 진입가: 2779000.00, 구매 개수: 0.0017 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2779000.00, 청산가: 2778000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 304, Hit Ratio: 50.66%, 누적 수익률: 0.9448
#
# 새로운 5분봉 생성: 2025-03-18 20:35:00
# 디버그: y_cont = 1.0252718925476074
# [진입] 상승 예측: KRW 잔고의 50%(4766 KRW)로 매수, 진입가: 2778000.00, 구매 개수: 0.0017 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2778000.00, 청산가: 2777000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 305, Hit Ratio: 50.49%, 누적 수익률: 0.9446
#
# 새로운 5분봉 생성: 2025-03-18 20:40:00
# 디버그: y_cont = 0.9383667707443237
# [진입] 상승 예측: KRW 잔고의 50%(4766 KRW)로 매수, 진입가: 2777000.00, 구매 개수: 0.0017 개
# UnderMinTotalBid
# [청산] Long 거래 - 진입가: 2777000.00, 청산가: 2774000.00, 거래 개수: 0.0017 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 306, Hit Ratio: 50.33%, 누적 수익률: 0.9442
#
# 새로운 5분봉 생성: 2025-03-18 20:45:00
# 디버그: y_cont = 0.0005111503414809704
# [진입] 하락 예측: 보유 코인의 50%(0.0032 개) 매도, 진입가: 2774000.00
# [청산] Short 거래 - 진입가: 2774000.00, 청산가: 2773000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 307, Hit Ratio: 50.49%, 누적 수익률: 0.9441
#
# 새로운 5분봉 생성: 2025-03-18 20:50:00
# 디버그: y_cont = 1.065677285194397
# [진입] 상승 예측: KRW 잔고의 50%(6563 KRW)로 매수, 진입가: 2773000.00, 구매 개수: 0.0024 개
# [청산] Long 거래 - 진입가: 2773000.00, 청산가: 2775000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 308, Hit Ratio: 50.65%, 누적 수익률: 0.9440
#
# 새로운 5분봉 생성: 2025-03-18 20:55:00
# 디버그: y_cont = 0.9602616429328918
# [진입] 상승 예측: KRW 잔고의 50%(5250 KRW)로 매수, 진입가: 2775000.00, 구매 개수: 0.0019 개
# [청산] Long 거래 - 진입가: 2775000.00, 청산가: 2779000.00, 거래 개수: 0.0019 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 309, Hit Ratio: 50.81%, 누적 수익률: 0.9441
#
# 새로운 5분봉 생성: 2025-03-18 21:00:00
# 디버그: y_cont = 0.024540264159440994
# [진입] 하락 예측: 보유 코인의 50%(0.0034 개) 매도, 진입가: 2779000.00
# [청산] Short 거래 - 진입가: 2779000.00, 청산가: 2780000.00, 거래 개수: 0.0034 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 310, Hit Ratio: 50.65%, 누적 수익률: 0.9438
#
# 새로운 5분봉 생성: 2025-03-18 21:05:00
# 디버그: y_cont = -0.007310781627893448
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2780000.00
# [청산] Short 거래 - 진입가: 2780000.00, 청산가: 2776000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 311, Hit Ratio: 50.80%, 누적 수익률: 0.9439
#
# 새로운 5분봉 생성: 2025-03-18 21:10:00
# 디버그: y_cont = -0.022497598081827164
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2774000.00
# [청산] Short 거래 - 진입가: 2774000.00, 청산가: 2778000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9995 (Miss)
# 거래 횟수: 312, Hit Ratio: 50.64%, 누적 수익률: 0.9435
#
# 새로운 5분봉 생성: 2025-03-18 21:15:00
# 디버그: y_cont = 1.0126945972442627
# [진입] 상승 예측: KRW 잔고의 50%(8863 KRW)로 매수, 진입가: 2777000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2777000.00, 청산가: 2785000.00, 거래 개수: 0.0032 개, 거래 수익률: 1.0004 (Hit)
# 거래 횟수: 313, Hit Ratio: 50.80%, 누적 수익률: 0.9438
#
# 새로운 5분봉 생성: 2025-03-18 21:20:00
# 디버그: y_cont = 0.0017337307799607515
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2785000.00
# [청산] Short 거래 - 진입가: 2785000.00, 청산가: 2788000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 314, Hit Ratio: 50.64%, 누적 수익률: 0.9434
#
# 새로운 5분봉 생성: 2025-03-18 21:25:00
# 디버그: y_cont = 0.007685627788305283
# [진입] 하락 예측: 보유 코인의 50%(0.0019 개) 매도, 진입가: 2788000.00
# [청산] Short 거래 - 진입가: 2788000.00, 청산가: 2787000.00, 거래 개수: 0.0019 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 315, Hit Ratio: 50.79%, 누적 수익률: 0.9433
#
# 새로운 5분봉 생성: 2025-03-18 21:30:00
# 디버그: y_cont = -0.048280972987413406
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2787000.00
# [청산] Short 거래 - 진입가: 2787000.00, 청산가: 2784000.00, 거래 개수: 0.0015 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 316, Hit Ratio: 50.95%, 누적 수익률: 0.9433
#
# 새로운 5분봉 생성: 2025-03-18 21:35:00
# 디버그: y_cont = -0.01767381839454174
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2784000.00
# [청산] Short 거래 - 진입가: 2784000.00, 청산가: 2784000.00, 거래 개수: 0.0015 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 317, Hit Ratio: 51.10%, 누적 수익률: 0.9431
#
# 새로운 5분봉 생성: 2025-03-18 21:40:00
# 디버그: y_cont = -0.00093382055638358
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2784000.00
# [청산] Short 거래 - 진입가: 2784000.00, 청산가: 2790000.00, 거래 개수: 0.0015 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 318, Hit Ratio: 50.94%, 누적 수익률: 0.9425
#
# 새로운 5분봉 생성: 2025-03-18 21:45:00
# 디버그: y_cont = -0.014520998112857342
# [진입] 하락 예측: 보유 코인의 50%(0.0015 개) 매도, 진입가: 2790000.00
# [청산] Short 거래 - 진입가: 2790000.00, 청산가: 2787000.00, 거래 개수: 0.0015 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 319, Hit Ratio: 51.10%, 누적 수익률: 0.9425
#
# 새로운 5분봉 생성: 2025-03-18 21:50:00
# 디버그: y_cont = 1.0124014616012573
# [진입] 상승 예측: KRW 잔고의 50%(9497 KRW)로 매수, 진입가: 2787000.00, 구매 개수: 0.0034 개
# [청산] Long 거래 - 진입가: 2787000.00, 청산가: 2791000.00, 거래 개수: 0.0034 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 320, Hit Ratio: 51.25%, 누적 수익률: 0.9426
#
# 새로운 5분봉 생성: 2025-03-18 21:55:00
# 디버그: y_cont = 0.01810520701110363
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2791000.00
# [청산] Short 거래 - 진입가: 2791000.00, 청산가: 2784000.00, 거래 개수: 0.0022 개, 거래 수익률: 1.0003 (Hit)
# 거래 횟수: 321, Hit Ratio: 51.40%, 누적 수익률: 0.9429
#
# 새로운 5분봉 생성: 2025-03-18 22:00:00
# 디버그: y_cont = -0.011160719208419323
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2784000.00
# [청산] Short 거래 - 진입가: 2784000.00, 청산가: 2784000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 322, Hit Ratio: 51.55%, 누적 수익률: 0.9427
#
# 새로운 5분봉 생성: 2025-03-18 22:05:00
# 디버그: y_cont = 0.006708348169922829
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2784000.00
# [청산] Short 거래 - 진입가: 2784000.00, 청산가: 2785000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 323, Hit Ratio: 51.39%, 누적 수익률: 0.9425
#
# 새로운 5분봉 생성: 2025-03-18 22:10:00
# 디버그: y_cont = 0.026145050302147865
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2785000.00
# [청산] Short 거래 - 진입가: 2785000.00, 청산가: 2783000.00, 거래 개수: 0.0018 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 324, Hit Ratio: 51.54%, 누적 수익률: 0.9424
#
# 새로운 5분봉 생성: 2025-03-18 22:15:00
# 디버그: y_cont = 0.9927374124526978
# [진입] 상승 예측: KRW 잔고의 50%(8832 KRW)로 매수, 진입가: 2783000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2783000.00, 청산가: 2786000.00, 거래 개수: 0.0032 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 325, Hit Ratio: 51.69%, 누적 수익률: 0.9424
#
# 새로운 5분봉 생성: 2025-03-18 22:20:00
# 디버그: y_cont = 0.5680301189422607
# [진입] 상승 예측: KRW 잔고의 50%(7065 KRW)로 매수, 진입가: 2786000.00, 구매 개수: 0.0025 개
# [청산] Long 거래 - 진입가: 2786000.00, 청산가: 2789000.00, 거래 개수: 0.0025 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 326, Hit Ratio: 51.84%, 누적 수익률: 0.9424
#
# 새로운 5분봉 생성: 2025-03-18 22:25:00
# 디버그: y_cont = 0.021966665983200073
# [진입] 하락 예측: 보유 코인의 50%(0.0029 개) 매도, 진입가: 2791000.00
# [청산] Short 거래 - 진입가: 2791000.00, 청산가: 2790000.00, 거래 개수: 0.0029 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 327, Hit Ratio: 51.99%, 누적 수익률: 0.9423
#
# 새로운 5분봉 생성: 2025-03-18 22:30:00
# 디버그: y_cont = 1.0073660612106323
# [진입] 상승 예측: KRW 잔고의 50%(7277 KRW)로 매수, 진입가: 2790000.00, 구매 개수: 0.0026 개
# [청산] Long 거래 - 진입가: 2790000.00, 청산가: 2783000.00, 거래 개수: 0.0026 개, 거래 수익률: 0.9993 (Miss)
# 거래 횟수: 328, Hit Ratio: 51.83%, 누적 수익률: 0.9417
#
# 새로운 5분봉 생성: 2025-03-18 22:35:00
# 디버그: y_cont = 0.02791213057935238
# [진입] 하락 예측: 보유 코인의 50%(0.0029 개) 매도, 진입가: 2783000.00
# [청산] Short 거래 - 진입가: 2783000.00, 청산가: 2770000.00, 거래 개수: 0.0029 개, 거래 수익률: 1.0007 (Hit)
# 거래 횟수: 329, Hit Ratio: 51.98%, 누적 수익률: 0.9424
#
# 새로운 5분봉 생성: 2025-03-18 22:40:00
# 디버그: y_cont = 0.9518263936042786
# [진입] 상승 예측: KRW 잔고의 50%(7409 KRW)로 매수, 진입가: 2770000.00, 구매 개수: 0.0027 개
# [청산] Long 거래 - 진입가: 2770000.00, 청산가: 2764000.00, 거래 개수: 0.0027 개, 거래 수익률: 0.9994 (Miss)
# 거래 횟수: 330, Hit Ratio: 51.82%, 누적 수익률: 0.9418
#
# 새로운 5분봉 생성: 2025-03-18 22:45:00
# 디버그: y_cont = 0.04634500667452812
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2764000.00
# [청산] Short 거래 - 진입가: 2764000.00, 청산가: 2767000.00, 거래 개수: 0.0028 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 331, Hit Ratio: 51.66%, 누적 수익률: 0.9414
#
# 새로운 5분봉 생성: 2025-03-18 22:50:00
# 디버그: y_cont = 1.0178892612457275
# [진입] 상승 예측: KRW 잔고의 50%(7482 KRW)로 매수, 진입가: 2767000.00, 구매 개수: 0.0027 개
# [청산] Long 거래 - 진입가: 2767000.00, 청산가: 2771000.00, 거래 개수: 0.0027 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 332, Hit Ratio: 51.81%, 누적 수익률: 0.9415
#
# 새로운 5분봉 생성: 2025-03-18 22:55:00
# 디버그: y_cont = -0.0063193305395543575
# [진입] 하락 예측: 보유 코인의 50%(0.0028 개) 매도, 진입가: 2771000.00
# [청산] Short 거래 - 진입가: 2771000.00, 청산가: 2768000.00, 거래 개수: 0.0028 개, 거래 수익률: 1.0000 (Hit)
# 거래 횟수: 333, Hit Ratio: 51.95%, 누적 수익률: 0.9415
#
# 새로운 5분봉 생성: 2025-03-18 23:00:00
# 디버그: y_cont = -0.034945033490657806
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2768000.00
# [청산] Short 거래 - 진입가: 2768000.00, 청산가: 2769000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9997 (Miss)
# 거래 횟수: 334, Hit Ratio: 51.80%, 누적 수익률: 0.9412
#
# 새로운 5분봉 생성: 2025-03-18 23:05:00
# 디버그: y_cont = 0.9200373888015747
# [진입] 상승 예측: KRW 잔고의 50%(8769 KRW)로 매수, 진입가: 2772000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2772000.00, 청산가: 2774000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 335, Hit Ratio: 51.94%, 누적 수익률: 0.9412
#
# 새로운 5분봉 생성: 2025-03-18 23:10:00
# 디버그: y_cont = 0.002813497791066766
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2774000.00
# [청산] Short 거래 - 진입가: 2774000.00, 청산가: 2772000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 336, Hit Ratio: 52.08%, 누적 수익률: 0.9411
#
# 새로운 5분봉 생성: 2025-03-18 23:15:00
# 디버그: y_cont = -0.001020905445329845
# [진입] 하락 예측: 보유 코인의 50%(0.0019 개) 매도, 진입가: 2773000.00
# [청산] Short 거래 - 진입가: 2773000.00, 청산가: 2771000.00, 거래 개수: 0.0019 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 337, Hit Ratio: 52.23%, 누적 수익률: 0.9411
#
# 새로운 5분봉 생성: 2025-03-18 23:20:00
# 디버그: y_cont = -0.008309661410748959
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2771000.00
# [청산] Short 거래 - 진입가: 2771000.00, 청산가: 2778000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9993 (Miss)
# 거래 횟수: 338, Hit Ratio: 52.07%, 누적 수익률: 0.9404
#
# 새로운 5분봉 생성: 2025-03-18 23:25:00
# 디버그: y_cont = -0.015116933733224869
# [진입] 하락 예측: 보유 코인의 50%(0.0016 개) 매도, 진입가: 2780000.00
# [청산] Short 거래 - 진입가: 2780000.00, 청산가: 2780000.00, 거래 개수: 0.0016 개, 거래 수익률: 0.9998 (Hit)
# 거래 횟수: 339, Hit Ratio: 52.21%, 누적 수익률: 0.9402
#
# 새로운 5분봉 생성: 2025-03-18 23:30:00
# 디버그: y_cont = 0.9867480397224426
# [진입] 상승 예측: KRW 잔고의 50%(9431 KRW)로 매수, 진입가: 2780000.00, 구매 개수: 0.0034 개
# [청산] Long 거래 - 진입가: 2780000.00, 청산가: 2782000.00, 거래 개수: 0.0034 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 340, Hit Ratio: 52.35%, 누적 수익률: 0.9402
#
# 새로운 5분봉 생성: 2025-03-18 23:35:00
# 디버그: y_cont = 0.004766351543366909
# [진입] 하락 예측: 보유 코인의 50%(0.0022 개) 매도, 진입가: 2781000.00
# [청산] Short 거래 - 진입가: 2781000.00, 청산가: 2784000.00, 거래 개수: 0.0022 개, 거래 수익률: 0.9996 (Miss)
# 거래 횟수: 341, Hit Ratio: 52.20%, 누적 수익률: 0.9398
#
# 새로운 5분봉 생성: 2025-03-18 23:40:00
# 디버그: y_cont = 0.014036855660378933
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2784000.00
# [청산] Short 거래 - 진입가: 2784000.00, 청산가: 2780000.00, 거래 개수: 0.0018 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 342, Hit Ratio: 52.34%, 누적 수익률: 0.9398
#
# 새로운 5분봉 생성: 2025-03-18 23:45:00
# 디버그: y_cont = -7.857124001020566e-05
# [진입] 하락 예측: 보유 코인의 50%(0.0018 개) 매도, 진입가: 2780000.00
# [청산] Short 거래 - 진입가: 2780000.00, 청산가: 2776000.00, 거래 개수: 0.0018 개, 거래 수익률: 1.0001 (Hit)
# 거래 횟수: 343, Hit Ratio: 52.48%, 누적 수익률: 0.9399
#
# 새로운 5분봉 생성: 2025-03-18 23:50:00
# 디버그: y_cont = 1.0135210752487183
# [진입] 상승 예측: KRW 잔고의 50%(8782 KRW)로 매수, 진입가: 2776000.00, 구매 개수: 0.0032 개
# [청산] Long 거래 - 진입가: 2776000.00, 청산가: 2778000.00, 거래 개수: 0.0032 개, 거래 수익률: 0.9999 (Hit)
# 거래 횟수: 344, Hit Ratio: 52.62%, 누적 수익률: 0.9399
#
# 새로운 5분봉 생성: 2025-03-18 23:55:00
# 디버그: y_cont = -0.009302510879933834
# [진입] 하락 예측: 보유 코인의 50%(0.0024 개) 매도, 진입가: 2778000.00
# [청산] Short 거래 - 진입가: 2778000.00, 청산가: 2786000.00, 거래 개수: 0.0024 개, 거래 수익률: 0.9992 (Miss)
# 거래 횟수: 345, Hit Ratio: 52.46%, 누적 수익률: 0.9391
#
# 새로운 5분봉 생성: 2025-03-19 00:00:00
# 디버그: y_cont = 0.9856269359588623
# [진입] 상승 예측: KRW 잔고의 50%(8365 KRW)로 매수, 진입가: 2786000.00, 구매 개수: 0.0030 개
# [청산] Long 거래 - 진입가: 2786000.00, 청산가: 2779000.00, 거래 개수: 0.0030 개, 거래 수익률: 0.9993 (Miss)
# 거래 횟수: 346, Hit Ratio: 52.31%, 누적 수익률: 0.9385
#
# 새로운 5분봉 생성: 2025-03-19 00:05:00
# 디버그: y_cont = -0.025114307180047035
# [진입] 하락 예측: 보유 코인의 50%(0.0025 개) 매도, 진입가: 2779000.00
# [청산] Short 거래 - 진입가: 2779000.00, 청산가: 2774000.00, 거래 개수: 0.0025 개, 거래 수익률: 1.0002 (Hit)
# 거래 횟수: 347, Hit Ratio: 52.45%, 누적 수익률: 0.9386
#
# 새로운 5분봉 생성: 2025-03-19 00:10:00
# 디버그: y_cont = -0.01437176764011383
# [진입] 하락 예측: 보유 코인의 50%(0.0020 개) 매도, 진입가: 2774000.00
# [청산] Short 거래 - 진입가: 2774000.00, 청산가: 2781000.00, 거래 개수: 0.0020 개, 거래 수익률: 0.9993 (Miss)
# 거래 횟수: 348, Hit Ratio: 52.30%, 누적 수익률: 0.9380
#
# 새로운 5분봉 생성: 2025-03-19 00:15:00
# 디버그: y_cont = 0.9948108196258545
# [진입] 상승 예측: KRW 잔고의 50%(9221 KRW)로 매수, 진입가: 2781000.00, 구매 개수: 0.0033 개
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 267
#     265 except Exception as e:
#     266     notify(f"에러 발생: {e}")
# --> 267 time.sleep(10)
#
# KeyboardInterrupt:

# %% [markdown]
# CSDI version1

# %%
import time
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import pyupbit
import requests

##############################################
# LINE Notify 설정
##############################################
TARGET_URL = 'https://notify-api.line.me/api/notify'
TOKEN = "rlMIJRZSatEVj5MLBSqC0iVVRIM7trYKqVbwizh7gUL"
def send_line_notification(message):
    headers = {
        "Authorization": f"Bearer {TOKEN}",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"message": message}
    response = requests.post(TARGET_URL, headers=headers, data=data)
    return response

def notify(message):
    print(message)
    send_line_notification(message)

##############################################
# 전처리 함수: rolling minmax scaling 및 binning
##############################################
def rolling_minmax_scale(series, window=24):
    roll_min = series.rolling(window=window, min_periods=window).min()
    roll_max = series.rolling(window=window, min_periods=window).max()
    scaled = (series - roll_min) / ((roll_max - roll_min) + 1e-8)
    scaled = scaled.replace([np.inf, -np.inf], np.nan)
    scaled = scaled.fillna(1.0)
    return scaled.clip(upper=1.0)

def bin_and_encode(data, features, bins=100, drop_original=True):
    for feature in features:
        data[f'{feature}_Bin'] = pd.cut(data[feature], bins=bins, labels=False)
        one_hot = pd.get_dummies(data[f'{feature}_Bin'], prefix=f'{feature}_Bin').astype(np.int32)
        expected_columns = [f'{feature}_Bin_{i}' for i in range(bins)]
        one_hot = one_hot.reindex(columns=expected_columns, fill_value=0)
        data = pd.concat([data, one_hot], axis=1)
        if drop_original:
            data.drop(columns=[f'{feature}_Bin'], inplace=True)
    numeric_cols = data.select_dtypes(include=[np.number]).columns.tolist()
    for col in numeric_cols:
        data[col] = data[col].astype(np.float32)
    return data

##############################################
# Diffusion 모델 구성 (학습/추론용, 기존 코드와 동일)
##############################################
class ConditionEncoder(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim):
        super(ConditionEncoder, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim * lookback, condition_dim),
            nn.ReLU(),
            nn.Linear(condition_dim, condition_dim)
        )
        
    def forward(self, x):
        batch_size = x.size(0)
        x = x.contiguous().view(batch_size, -1)
        return self.fc(x)

class DiffusionClassifier(nn.Module):
    def __init__(self, input_dim, lookback, condition_dim=128, num_timesteps=100, hidden_dim=128):
        super(DiffusionClassifier, self).__init__()
        self.num_timesteps = num_timesteps
        betas = torch.linspace(1e-4, 0.02, num_timesteps)
        alphas = 1 - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)
        self.register_buffer('betas', betas)
        self.register_buffer('alphas', alphas)
        self.register_buffer('alphas_cumprod', alphas_cumprod)
        
        self.condition_encoder = ConditionEncoder(input_dim, lookback, condition_dim)
        self.time_embedding = nn.Embedding(num_timesteps, hidden_dim)
        self.model = nn.Sequential(
            nn.Linear(1 + condition_dim + hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )
        
    def forward(self, x_condition, y_noisy, t):
        cond = self.condition_encoder(x_condition)
        t_emb = self.time_embedding(t)
        inp = torch.cat([y_noisy, cond, t_emb], dim=1)
        predicted_noise = self.model(inp)
        return predicted_noise
    
    def sample(self, x_condition, device):
        batch_size = x_condition.size(0)
        y = torch.randn(batch_size, 1, device=device)
        for t in reversed(range(self.num_timesteps)):
            t_tensor = torch.full((batch_size,), t, device=device, dtype=torch.long)
            predicted_noise = self.forward(x_condition, y, t_tensor)
            alpha = self.alphas[t]
            alpha_cumprod = self.alphas_cumprod[t]
            beta = self.betas[t]
            y = (1 / torch.sqrt(alpha)) * (y - (beta / torch.sqrt(1 - alpha_cumprod)) * predicted_noise)
            if t > 0:
                noise = torch.randn_like(y)
                y = y + torch.sqrt(beta) * noise
        return y

##############################################
# 모델 로드 (학습된 모델 파일을 로드)
##############################################
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
input_dim = 400  # OHLC 4개 feature, 각 100구간 → 총 400차원
lookback = 24
model = DiffusionClassifier(input_dim=input_dim, lookback=lookback, condition_dim=128, num_timesteps=100, hidden_dim=128).to(device)
model_path = "diffusion_model_experiment_14_24_csdi.pth"  # 학습된 모델 파일 경로 (필요에 따라 수정)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

##############################################
# 업비트 거래를 위한 pyupbit API 설정
##############################################
upbit_access = "x03uKM3uyZ9RNDBHLxauEaeI6X8pdKQq8rHG2wvx"
upbit_secret = "e9UyPqJBjCvNDxCmtx7bdPaHtAEgw2Ftxu3UpuJc"
upbit = pyupbit.Upbit(upbit_access, upbit_secret)
ticker = "KRW-ETH"  # 거래할 코인 티커

##############################################
# 모델 예측 함수: 최근 50개의 5분봉 데이터를 전처리한 후 예측
##############################################
def get_model_prediction():
    """
    pyupbit로 최근 50개의 5분봉 데이터를 가져와 전처리한 후,
    마지막 lookback 개 봉을 diffusion model의 조건으로 사용하여
    reverse diffusion sampling을 통해 다음 5분봉의 close (continuous) 값을 예측하고,
    이전 close와 비교하여 상승/하락 방향을 결정.
    
    추가로, 예측된 변화율이 ±0.1% 이내이면 hold로 간주하고, 
    변화율이 크면 그 비율에 따라 거래 금액을 산정하기 위한 변화율을 함께 반환.
    """
    df = pyupbit.get_ohlcv(ticker, interval="minute5", count=50)
    if df is None or len(df) < lookback:
        notify("예측에 충분한 데이터가 없습니다.")
        return None, None
    ohlc_features = ['open', 'high', 'low', 'close']
    for feature in ohlc_features:
        df[feature] = rolling_minmax_scale(df[feature], window=24)
    df_processed = bin_and_encode(df.copy(), ohlc_features, bins=100, drop_original=True)
    final_input_columns = [col for col in df_processed.columns if '_Bin_' in col]
    if len(df_processed) < lookback:
        notify("lookback 데이터가 부족합니다.")
        return None, None
    input_seq = df_processed[final_input_columns].iloc[-lookback:]
    x = torch.tensor(input_seq.values, dtype=torch.float32).unsqueeze(0).to(device)
    # 이전 close (실제 거래 시 비교용)
    prev_close = df['close'].iloc[-2]
    with torch.no_grad():
        predicted_close = model.sample(x, device).item()  # 예측된 다음 close 값 (continuous)
        notify("디버그: predicted_close = " + str(predicted_close))
        # 변화율 계산: (predicted - previous) / previous
        pct_change = (predicted_close - prev_close) / prev_close
        # 만약 변화율이 ±0.1% 이내이면 hold (0)
        if abs(pct_change) < 0.001:
            prediction = 0  # hold: 여기서는 0으로 간주 (실제 거래 로직에서 별도 처리 필요)
        else:
            # 상승이면 1, 하락이면 -1 (거래 비율 산정을 위해)
            prediction = 1 if pct_change > 0 else -1
    return prediction, pct_change

##############################################
# 거래 실행 함수: 예측에 따라 거래를 실행 (매수/매도 비율 결정)
##############################################
def trade_decision():
    prediction, pct_change = get_model_prediction()
    if prediction is None:
        return
    entry_price = pyupbit.get_current_price(ticker)
    if entry_price is None:
        notify("현재가를 조회하지 못했습니다.")
        return
    # hold 조건: 변화율이 ±0.1% 이내이면 아무 거래도 하지 않음.
    if abs(pct_change) < 0.001:
        notify("예측 변화율이 미미하여 거래를 진행하지 않습니다 (Hold).")
        return
    # 거래 비율은 예측 변화율의 절대값에 비례시키되, 최대 거래 비율 제한 (예: 20%)을 둠.
    max_trade_fraction = 0.2
    trade_fraction = min(max_trade_fraction, max_trade_fraction * abs(pct_change) * 10)  # 조정 인자
    if prediction > 0:
        # 상승 예측: 매수 → 보유 KRW의 trade_fraction 만큼 매수
        krw_balance = upbit.get_balance("KRW")
        if krw_balance is None or krw_balance < 5000:
            notify("매수할 충분한 KRW 잔고가 없습니다.")
            return
        trade_amount = krw_balance * trade_fraction
        notify(f"[진입] 상승 예측: 예측 변화율 {pct_change*100:.2f}% → KRW 잔고의 {trade_fraction*100:.1f}% ({trade_amount:.0f} KRW)로 매수, 진입가: {entry_price:.2f}")
        upbit.buy_market_order(ticker, trade_amount)
    else:
        # 하락 예측: 매도 → 보유 코인의 trade_fraction 만큼 매도
        coin = ticker.split("-")[1]
        coin_balance = upbit.get_balance(coin)
        if coin_balance is None or coin_balance <= 0:
            notify("매도할 보유 코인이 없습니다.")
            return
        trade_amount = coin_balance * trade_fraction
        notify(f"[진입] 하락 예측: 예측 변화율 {pct_change*100:.2f}% → 보유 코인의 {trade_fraction*100:.1f}% ({trade_amount:.4f} 개) 매도, 진입가: {entry_price:.2f}")
        upbit.sell_market_order(ticker, trade_amount)

##############################################
# 거래 결과 처리 함수: 청산 시점에 거래 결과를 계산
##############################################
def process_pending_trade():
    global pending_trade, stats
    if pending_trade is None:
        return
    exit_price = pyupbit.get_current_price(ticker)
    if exit_price is None:
        notify("청산 가격을 조회하지 못했습니다.")
        return
    direction = pending_trade['direction']
    entry_price = pending_trade['entry_price']
    fee = 0.0005  # 0.05%
    if direction == 1:  # Long 거래: 상승 예측
        fraction = pending_trade.get('trade_fraction', 0.2)
        effective_factor = (exit_price * (1 - fee)) / (entry_price * (1 + fee))
        trade_return = 1 + fraction * (effective_factor - 1)
        trade_type = "Long"
        outcome = "Hit" if exit_price > entry_price else "Miss"
    else:  # Short 거래: 하락 예측
        fraction = pending_trade.get('trade_fraction', 0.2)
        effective_factor = (entry_price * (1 - fee)) / (exit_price * (1 + fee))
        trade_return = 1 + fraction * (effective_factor - 1)
        trade_type = "Short"
        outcome = "Hit" if exit_price <= entry_price else "Miss"
    
    stats['total_trades'] += 1
    if outcome == "Hit":
        stats['win_count'] += 1
    stats['cumulative_return'] *= trade_return
    stats['trade_returns'].append(trade_return)
    quantity = pending_trade.get('quantity', 0)
    notify(f"[청산] {trade_type} 거래 - 진입가: {entry_price:.2f}, 청산가: {exit_price:.2f}, 거래 개수: {quantity:.4f} 개, 거래 수익률: {trade_return:.4f} ({outcome})")
    hit_ratio = stats['win_count'] / stats['total_trades'] if stats['total_trades'] > 0 else 0
    notify(f"거래 횟수: {stats['total_trades']}, Hit Ratio: {hit_ratio:.2%}, 누적 수익률: {stats['cumulative_return']:.4f}\n")
    pending_trade = None

##############################################
# 글로벌 변수: 진행 중 거래 정보 및 거래 통계
##############################################
pending_trade = None
stats = {
    'total_trades': 0,
    'win_count': 0,
    'cumulative_return': 1.0,
    'trade_returns': []
}

##############################################
# 메인 거래 루프: 새로운 5분봉 생성 시마다 거래 결정
##############################################
last_candle_time = None
while True:
    try:
        df = pyupbit.get_ohlcv(ticker, interval="minute5", count=1)
        if df is not None and not df.empty:
            current_candle_time = df.index[-1]
            if last_candle_time is None or current_candle_time > last_candle_time:
                if pending_trade is not None:
                    process_pending_trade()
                notify(f"새로운 5분봉 생성: {current_candle_time}")
                trade_decision()
                last_candle_time = current_candle_time
        else:
            notify("최신 5분봉 데이터를 불러오지 못했습니다.")
    except Exception as e:
        notify(f"에러 발생: {e}")
    time.sleep(10)
# Out:
# 새로운 5분봉 생성: 2025-03-22 11:25:00
# 디버그: predicted_close = 0.6518999934196472
# [진입] 상승 예측: 예측 변화율 17.34% → KRW 잔고의 20.0% (14020 KRW)로 매수, 진입가: 2930000.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 277
#     275 except Exception as e:
#     276     notify(f"에러 발생: {e}")
# --> 277 time.sleep(10)
#
# KeyboardInterrupt:
